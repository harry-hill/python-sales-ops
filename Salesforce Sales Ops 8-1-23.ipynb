# %% [markdown]
# # Salesforce Sales Ops 8-1-23
# Harry Hill

# %% [markdown]
# ### Outstanding hotfixes:
# - 110/4532 rows not given a Contact Level; investigate final gaps manually and add into regex's
# - make sure none of the Department labels overwrite each other
# - manually check for Accounting and Legal titles (0 came up)
# - some phone numbers in XXX-XXX-XXXX format; want them transformed?

# %% [markdown]
# ## Import dataset

# %%
import pandas as pd
import numpy as np
import re
from titlecase import titlecase

file = '08-1-23 Sales Ops NEW for Harry.xlsx'

df = pd.read_excel(file)

df.head(50)
# Out:
#                        Account Name First Name   Last Name  \
# 0                   1-800-GOT-JUNK?       Yves    Laflamme
# 1                       100 Thieves     Kelsey     Schultz
# 2                               10K       Nick        Hamm
# 3                               10K    Matthew        Lamb
# 4                               10K      Jared      Miller
# 5               160 Driving Academy        Rob      Dearth
# 6                  174 Power Global      David        Park
# 7                         1Password    Jessica  Coscarelli
# 8                         1Password      Emily       Payne
# 9                   1Stdibs.Com Inc  Charlotte     Noordsy
# 10                       1WorldSync      Renee      Gerami
# 11        2-10 Home Buyers Warranty    Zachary    Ratzlaff
# 12        2-10 Home Buyers Warranty       Zach    Ratzlaff
# 13        3 Creeks Technologies LLC      Scott        Aker
# 14                        3BL Media      Emily       Tuohy
# 15                     3STEP Sports      Deion      Wilson
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 18                    5P Consulting      Randy    Jasinski
# 19                    5P Consulting    Y'vonne       Sisco
# 20                           6sense      Ankit       Goyal
# 21                  6Street Digital    Johnson         Tai
# 22                        8x8, Inc.     Helena      Ostlin
# 23                        8x8, Inc.    Barbara    Phillips
# 24               A&M Wood Specialty    Raphael   Giuffrida
# 25                               A5      Bryan       Musto
# 26                    AAA Carolinas     Claire    Crabtree
# 27                AAA Club Alliance       John        Cccm
# 28                             AAGI      Brian        Cook
# 29             Ability Network Inc.      Kelli       Davis
# 30            Academic Partnerships    Mengyao        Chen
# 31                            ACASS     Shauna      Dunham
# 32         Accelerated Systems Inc.    Marcell     Alvarez
# 33                           Accern  Yugandhar           P
# 34  Access | Information Management      Cindy     Barrios
# 35               Access Development       Jodi         Lee
# 36                          AccuTec      Carla       Floyd
# 37                   Achievers Corp    Mustafa        Avci
# 38                     ACI Learning   Madeline       Doyle
# 39                     ACI Learning     Cheryl       Janda
# 40                     ACI Learning      Pedro        Lima
# 41                     ACI Learning       Vito      Lucero
# 42                     ACI Learning    William     Mathias
# 43                     ACI Learning      Dylan   Stenulson
# 44                     ACI Learning    Jessica     Walters
# 45                    ACI Worldwide      Johan      Amador
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 48                     Acra Lending      Jason    Sheridan
# 49               Actian Corporation       Paul     Navarro
#
#                                                 Title  \
# 0                           Manager, Sales Enablement
# 1   Director, Head of Sales Operations and Activat...
# 2                                     Founder and CEO
# 3                            Chief Technology Officer
# 4                                                 COO
# 5   Head of Contact Center Operations, Truckers Ne...
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 8                            Sales Enablement Manager
# 9                           Manager, Sales Operations
# 10         Director of Technology Planning & Delivery
# 11                           Sales Operations Manager
# 12                           Sales Operations Manager
# 13                                      Owner/Founder
# 14                         Revenue Operations Manager
# 15                        Sales Operations Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and operations coordinator
# 18                                President / Partner
# 19                                      Founder / CEO
# 20                            Sr. Integration Manager
# 21                               Salesforce Developer
# 22                   Senior Manager, Sales Operations
# 23              Sales Onboarding & Enablement Manager
# 24                         Sales Operations Team Lead
# 25  Vice President, Head of FINS & Digital Experience
# 26                           Salesforce Administrator
# 27  Manager Insurance Agency Retention Sales Opera...
# 28                                  Western Sales, VP
# 29                    Senior Manager Sales Operations
# 30                           Sales Operations Manager
# 31                           Manager of Sales Support
# 32                       Sales Operations Coordinator
# 33                                 Salesforce Manager
# 34  Corporate Development Advisor - M&A / Corporat...
# 35                                Sales Support Admin
# 36                        Sales Operations Specialist
# 37                Manager, Revenue Operations Systems
# 38                           Salesforce Administrator
# 39  Sr. Director of Salesforce Development and Int...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 42  Global Head, Sales Enablement Services and Rev...
# 43                        Sales Enablement Specialist
# 44                        Sales Operations Specialist
# 45                    Head of Global Sales Operations
# 46  Senior Director of Revenue Programs, Planning ...
# 47       Senior Manager, Revenue Operations, Programs
# 48                    Vice President, Wholesale Sales
# 49                              Support Sales Manager
#
#                                     Email             Phone Mobile  \
# 0           yves.laflamme@1800gotjunk.com   +1 800-468-5865    NaN
# 1                k.schultz@100thieves.com    (424) 298-0196    NaN
# 2                        nick@10kview.com               NaN    NaN
# 3                        matt@10kview.com               NaN    NaN
# 4                       jared@10kview.com               NaN    NaN
# 5           rdearth@160drivingacademy.com    (877) 350-0884    NaN
# 6           david.park@174powerglobal.com   +1 949-748-5970    NaN
# 7        jessica.coscarelli@agilebits.com    (888) 710-9976    NaN
# 8               emily.payne@1password.com    (888) 710-9976    NaN
# 9           charlotte.noordsy@1stdibs.com    (877) 721-3427    NaN
# 10                 rgerami@1worldsync.com    (866) 280-4013    NaN
# 11                    zaratzlaff@2-10.com    (720) 747-6000    NaN
# 12                     zratzlaff@2-10.com    (720) 747-6000    NaN
# 13                  scott@3creekstech.com               NaN    NaN
# 14                    etuohy@3blmedia.com    (866) 508-0993    NaN
# 15             deion.wilson@threestep.com    (781) 722-0338    NaN
# 16                vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                   ggolzari@4refuel.com   +1 888-473-3835    NaN
# 18             rjasinski@5pconsulting.biz   +1 760-652-9127    NaN
# 19               yormond@5pconsulting.biz   +1 760-652-9127    NaN
# 20                 ankit.goyal@6sense.com   +1 415-305-5951    NaN
# 21                     johnson.tai@6st.co  +1(833) 242-6439    NaN
# 22                  helena.ostlin@8x8.com    (844) 716-2409    NaN
# 23               barbara.phillips@8x8.com    (844) 716-2409    NaN
# 24         rgiuffrida@forloversofwood.com   +1 519-653-9322    NaN
# 25                      bmusto@a5corp.com    (844) 226-6344    NaN
# 26                         claire@aaa.com    (800) 222-4357    NaN
# 27             jstassi@aaamidatlantic.com    (800) 222-4357    NaN
# 28                        brianc@aagi.com  +1(888) 442-2886    NaN
# 29               kelli.davis@inovalon.com    (612) 460-4301    NaN
# 30  mengyao.chen@academicpartnerships.com    (214) 210-7300    NaN
# 31                      sdunham@acass.com    (514) 636-1099    NaN
# 32  marcellalvarez@acceleratedsystems.com   +1 519-342-2507    NaN
# 33                 yugandhar.p@accern.com   +1 347-256-8460    NaN
# 34                cbarrios@accesscorp.com    (973) 808-2885    NaN
# 35         jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN
# 36               carla.floyd@atblades.com   +1 800-336-4061    NaN
# 37              tugrul.avci@achievers.com    (888) 622-3343    NaN
# 38         madeline.doyle@acilearning.com    (719) 596-4545    NaN
# 39           cheryl.janda@acilearning.com    (719) 596-4545    NaN
# 40             pedro.lima@acilearning.com    (719) 596-4545    NaN
# 41                vlucero@leaderquest.net    (719) 596-4545    NaN
# 42           bill.mathias@acilearning.com    (719) 596-4545    NaN
# 43        dylan.stenulson@acilearning.com    (719) 596-4545    NaN
# 44        jessica.walters@acilearning.com    (719) 596-4545    NaN
# 45          johan.amador@aciworldwide.com    (844) 776-6605    NaN
# 46                  pam.bragan@acquia.com    (888) 922-7842    NaN
# 47         elizabeth.levasseur@acquia.com    (888) 922-7842    NaN
# 48         jsheridan@citadelservicing.com  +1(888) 800-7661    NaN
# 49                paul.navarro@actian.com    (650) 587-5500    NaN
#
#    Contact Level  Department
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 15           NaN         NaN
# 16           NaN         NaN
# 17           NaN         NaN
# 18           NaN         NaN
# 19           NaN         NaN
# 20           NaN         NaN
# 21           NaN         NaN
# 22           NaN         NaN
# 23           NaN         NaN
# 24           NaN         NaN
# 25           NaN         NaN
# 26           NaN         NaN
# 27           NaN         NaN
# 28           NaN         NaN
# 29           NaN         NaN
# 30           NaN         NaN
# 31           NaN         NaN
# 32           NaN         NaN
# 33           NaN         NaN
# 34           NaN         NaN
# 35           NaN         NaN
# 36           NaN         NaN
# 37           NaN         NaN
# 38           NaN         NaN
# 39           NaN         NaN
# 40           NaN         NaN
# 41           NaN         NaN
# 42           NaN         NaN
# 43           NaN         NaN
# 44           NaN         NaN
# 45           NaN         NaN
# 46           NaN         NaN
# 47           NaN         NaN
# 48           NaN         NaN
# 49           NaN         NaN

# %% [markdown]
# ## 1. Convert 'Title'

# %%
# make a copy dataframe to edit
df2 = df.copy()
df2.head()
# Out:
#       Account Name First Name Last Name  \
# 0  1-800-GOT-JUNK?       Yves  Laflamme
# 1      100 Thieves     Kelsey   Schultz
# 2              10K       Nick      Hamm
# 3              10K    Matthew      Lamb
# 4              10K      Jared    Miller
#
#                                                Title  \
# 0                          Manager, Sales Enablement
# 1  Director, Head of Sales Operations and Activat...
# 2                                    Founder and CEO
# 3                           Chief Technology Officer
# 4                                                COO
#
#                            Email            Phone Mobile Contact Level  \
# 0  yves.laflamme@1800gotjunk.com  +1 800-468-5865    NaN           NaN
# 1       k.schultz@100thieves.com   (424) 298-0196    NaN           NaN
# 2               nick@10kview.com              NaN    NaN           NaN
# 3               matt@10kview.com              NaN    NaN           NaN
# 4              jared@10kview.com              NaN    NaN           NaN
#
#    Department
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# replace nulls in 'Title' with '-'
df2['Title'] = df2['Title'].fillna('-')
df2[df2['Title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Account Name, First Name, Last Name, Title, Email, Phone, Mobile, Contact Level, Department]
# Index: []

# %% [markdown]
# ### Make 'Title' column titlecase
# - i.e. coordinator -> Coordinator

# %%
df2['Title'] = df2['Title'].astype(str).apply(lambda x: titlecase(x))
df2.head(50)
# Out:
#                        Account Name First Name   Last Name  \
# 0                   1-800-GOT-JUNK?       Yves    Laflamme
# 1                       100 Thieves     Kelsey     Schultz
# 2                               10K       Nick        Hamm
# 3                               10K    Matthew        Lamb
# 4                               10K      Jared      Miller
# 5               160 Driving Academy        Rob      Dearth
# 6                  174 Power Global      David        Park
# 7                         1Password    Jessica  Coscarelli
# 8                         1Password      Emily       Payne
# 9                   1Stdibs.Com Inc  Charlotte     Noordsy
# 10                       1WorldSync      Renee      Gerami
# 11        2-10 Home Buyers Warranty    Zachary    Ratzlaff
# 12        2-10 Home Buyers Warranty       Zach    Ratzlaff
# 13        3 Creeks Technologies LLC      Scott        Aker
# 14                        3BL Media      Emily       Tuohy
# 15                     3STEP Sports      Deion      Wilson
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 18                    5P Consulting      Randy    Jasinski
# 19                    5P Consulting    Y'vonne       Sisco
# 20                           6sense      Ankit       Goyal
# 21                  6Street Digital    Johnson         Tai
# 22                        8x8, Inc.     Helena      Ostlin
# 23                        8x8, Inc.    Barbara    Phillips
# 24               A&M Wood Specialty    Raphael   Giuffrida
# 25                               A5      Bryan       Musto
# 26                    AAA Carolinas     Claire    Crabtree
# 27                AAA Club Alliance       John        Cccm
# 28                             AAGI      Brian        Cook
# 29             Ability Network Inc.      Kelli       Davis
# 30            Academic Partnerships    Mengyao        Chen
# 31                            ACASS     Shauna      Dunham
# 32         Accelerated Systems Inc.    Marcell     Alvarez
# 33                           Accern  Yugandhar           P
# 34  Access | Information Management      Cindy     Barrios
# 35               Access Development       Jodi         Lee
# 36                          AccuTec      Carla       Floyd
# 37                   Achievers Corp    Mustafa        Avci
# 38                     ACI Learning   Madeline       Doyle
# 39                     ACI Learning     Cheryl       Janda
# 40                     ACI Learning      Pedro        Lima
# 41                     ACI Learning       Vito      Lucero
# 42                     ACI Learning    William     Mathias
# 43                     ACI Learning      Dylan   Stenulson
# 44                     ACI Learning    Jessica     Walters
# 45                    ACI Worldwide      Johan      Amador
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 48                     Acra Lending      Jason    Sheridan
# 49               Actian Corporation       Paul     Navarro
#
#                                                 Title  \
# 0                           Manager, Sales Enablement
# 1   Director, Head of Sales Operations and Activat...
# 2                                     Founder and CEO
# 3                            Chief Technology Officer
# 4                                                 Coo
# 5   Head of Contact Center Operations, Truckers Ne...
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 8                            Sales Enablement Manager
# 9                           Manager, Sales Operations
# 10         Director of Technology Planning & Delivery
# 11                           Sales Operations Manager
# 12                           Sales Operations Manager
# 13                                      Owner/Founder
# 14                         Revenue Operations Manager
# 15                        Sales Operations Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 18                                President / Partner
# 19                                      Founder / CEO
# 20                            Sr. Integration Manager
# 21                               Salesforce Developer
# 22                   Senior Manager, Sales Operations
# 23              Sales Onboarding & Enablement Manager
# 24                         Sales Operations Team Lead
# 25  Vice President, Head of FINS & Digital Experience
# 26                           Salesforce Administrator
# 27  Manager Insurance Agency Retention Sales Opera...
# 28                                  Western Sales, VP
# 29                    Senior Manager Sales Operations
# 30                           Sales Operations Manager
# 31                           Manager of Sales Support
# 32                       Sales Operations Coordinator
# 33                                 Salesforce Manager
# 34  Corporate Development Advisor - M&A / Corporat...
# 35                                Sales Support Admin
# 36                        Sales Operations Specialist
# 37                Manager, Revenue Operations Systems
# 38                           Salesforce Administrator
# 39  Sr. Director of Salesforce Development and Int...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 42  Global Head, Sales Enablement Services and Rev...
# 43                        Sales Enablement Specialist
# 44                        Sales Operations Specialist
# 45                    Head of Global Sales Operations
# 46  Senior Director of Revenue Programs, Planning ...
# 47       Senior Manager, Revenue Operations, Programs
# 48                    Vice President, Wholesale Sales
# 49                              Support Sales Manager
#
#                                     Email             Phone Mobile  \
# 0           yves.laflamme@1800gotjunk.com   +1 800-468-5865    NaN
# 1                k.schultz@100thieves.com    (424) 298-0196    NaN
# 2                        nick@10kview.com               NaN    NaN
# 3                        matt@10kview.com               NaN    NaN
# 4                       jared@10kview.com               NaN    NaN
# 5           rdearth@160drivingacademy.com    (877) 350-0884    NaN
# 6           david.park@174powerglobal.com   +1 949-748-5970    NaN
# 7        jessica.coscarelli@agilebits.com    (888) 710-9976    NaN
# 8               emily.payne@1password.com    (888) 710-9976    NaN
# 9           charlotte.noordsy@1stdibs.com    (877) 721-3427    NaN
# 10                 rgerami@1worldsync.com    (866) 280-4013    NaN
# 11                    zaratzlaff@2-10.com    (720) 747-6000    NaN
# 12                     zratzlaff@2-10.com    (720) 747-6000    NaN
# 13                  scott@3creekstech.com               NaN    NaN
# 14                    etuohy@3blmedia.com    (866) 508-0993    NaN
# 15             deion.wilson@threestep.com    (781) 722-0338    NaN
# 16                vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                   ggolzari@4refuel.com   +1 888-473-3835    NaN
# 18             rjasinski@5pconsulting.biz   +1 760-652-9127    NaN
# 19               yormond@5pconsulting.biz   +1 760-652-9127    NaN
# 20                 ankit.goyal@6sense.com   +1 415-305-5951    NaN
# 21                     johnson.tai@6st.co  +1(833) 242-6439    NaN
# 22                  helena.ostlin@8x8.com    (844) 716-2409    NaN
# 23               barbara.phillips@8x8.com    (844) 716-2409    NaN
# 24         rgiuffrida@forloversofwood.com   +1 519-653-9322    NaN
# 25                      bmusto@a5corp.com    (844) 226-6344    NaN
# 26                         claire@aaa.com    (800) 222-4357    NaN
# 27             jstassi@aaamidatlantic.com    (800) 222-4357    NaN
# 28                        brianc@aagi.com  +1(888) 442-2886    NaN
# 29               kelli.davis@inovalon.com    (612) 460-4301    NaN
# 30  mengyao.chen@academicpartnerships.com    (214) 210-7300    NaN
# 31                      sdunham@acass.com    (514) 636-1099    NaN
# 32  marcellalvarez@acceleratedsystems.com   +1 519-342-2507    NaN
# 33                 yugandhar.p@accern.com   +1 347-256-8460    NaN
# 34                cbarrios@accesscorp.com    (973) 808-2885    NaN
# 35         jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN
# 36               carla.floyd@atblades.com   +1 800-336-4061    NaN
# 37              tugrul.avci@achievers.com    (888) 622-3343    NaN
# 38         madeline.doyle@acilearning.com    (719) 596-4545    NaN
# 39           cheryl.janda@acilearning.com    (719) 596-4545    NaN
# 40             pedro.lima@acilearning.com    (719) 596-4545    NaN
# 41                vlucero@leaderquest.net    (719) 596-4545    NaN
# 42           bill.mathias@acilearning.com    (719) 596-4545    NaN
# 43        dylan.stenulson@acilearning.com    (719) 596-4545    NaN
# 44        jessica.walters@acilearning.com    (719) 596-4545    NaN
# 45          johan.amador@aciworldwide.com    (844) 776-6605    NaN
# 46                  pam.bragan@acquia.com    (888) 922-7842    NaN
# 47         elizabeth.levasseur@acquia.com    (888) 922-7842    NaN
# 48         jsheridan@citadelservicing.com  +1(888) 800-7661    NaN
# 49                paul.navarro@actian.com    (650) 587-5500    NaN
#
#    Contact Level  Department
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 15           NaN         NaN
# 16           NaN         NaN
# 17           NaN         NaN
# 18           NaN         NaN
# 19           NaN         NaN
# 20           NaN         NaN
# 21           NaN         NaN
# 22           NaN         NaN
# 23           NaN         NaN
# 24           NaN         NaN
# 25           NaN         NaN
# 26           NaN         NaN
# 27           NaN         NaN
# 28           NaN         NaN
# 29           NaN         NaN
# 30           NaN         NaN
# 31           NaN         NaN
# 32           NaN         NaN
# 33           NaN         NaN
# 34           NaN         NaN
# 35           NaN         NaN
# 36           NaN         NaN
# 37           NaN         NaN
# 38           NaN         NaN
# 39           NaN         NaN
# 40           NaN         NaN
# 41           NaN         NaN
# 42           NaN         NaN
# 43           NaN         NaN
# 44           NaN         NaN
# 45           NaN         NaN
# 46           NaN         NaN
# 47           NaN         NaN
# 48           NaN         NaN
# 49           NaN         NaN

# %% [markdown]
# ### Make all acronyms in 'Title' column uppercase
# - must work on acronyms in titlecase i.e. Svp from previous step

# %%
# list of acronyms that should be uppercase from
acronym_list = ['CEO', 'CFO', 'COO', 'CSO', 'CRO', 'CMO', 'CTO', 'SVP', 'EVP', 'AVP', 'VP', 'AP', 'A/P', 'AR', 'A/R', 'AE', 'QA']

# Create a regular expression pattern that matches any acronyms in the list
pattern = r'\b(?:' + '|'.join(re.escape(acronym) for acronym in acronym_list) + r')\b'

# Function to convert matches to uppercase
def make_matches_uppercase(match):
    return match.group().upper()

# Apply the regular expression and conversion function to the 'Title' column
# re.sup expects a string, so converted column
df2['Title'] = df2['Title'].astype(str).apply(lambda x: re.sub(pattern, make_matches_uppercase, x, flags=re.IGNORECASE))

df2.head(50)
# Out:
#                        Account Name First Name   Last Name  \
# 0                   1-800-GOT-JUNK?       Yves    Laflamme
# 1                       100 Thieves     Kelsey     Schultz
# 2                               10K       Nick        Hamm
# 3                               10K    Matthew        Lamb
# 4                               10K      Jared      Miller
# 5               160 Driving Academy        Rob      Dearth
# 6                  174 Power Global      David        Park
# 7                         1Password    Jessica  Coscarelli
# 8                         1Password      Emily       Payne
# 9                   1Stdibs.Com Inc  Charlotte     Noordsy
# 10                       1WorldSync      Renee      Gerami
# 11        2-10 Home Buyers Warranty    Zachary    Ratzlaff
# 12        2-10 Home Buyers Warranty       Zach    Ratzlaff
# 13        3 Creeks Technologies LLC      Scott        Aker
# 14                        3BL Media      Emily       Tuohy
# 15                     3STEP Sports      Deion      Wilson
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 18                    5P Consulting      Randy    Jasinski
# 19                    5P Consulting    Y'vonne       Sisco
# 20                           6sense      Ankit       Goyal
# 21                  6Street Digital    Johnson         Tai
# 22                        8x8, Inc.     Helena      Ostlin
# 23                        8x8, Inc.    Barbara    Phillips
# 24               A&M Wood Specialty    Raphael   Giuffrida
# 25                               A5      Bryan       Musto
# 26                    AAA Carolinas     Claire    Crabtree
# 27                AAA Club Alliance       John        Cccm
# 28                             AAGI      Brian        Cook
# 29             Ability Network Inc.      Kelli       Davis
# 30            Academic Partnerships    Mengyao        Chen
# 31                            ACASS     Shauna      Dunham
# 32         Accelerated Systems Inc.    Marcell     Alvarez
# 33                           Accern  Yugandhar           P
# 34  Access | Information Management      Cindy     Barrios
# 35               Access Development       Jodi         Lee
# 36                          AccuTec      Carla       Floyd
# 37                   Achievers Corp    Mustafa        Avci
# 38                     ACI Learning   Madeline       Doyle
# 39                     ACI Learning     Cheryl       Janda
# 40                     ACI Learning      Pedro        Lima
# 41                     ACI Learning       Vito      Lucero
# 42                     ACI Learning    William     Mathias
# 43                     ACI Learning      Dylan   Stenulson
# 44                     ACI Learning    Jessica     Walters
# 45                    ACI Worldwide      Johan      Amador
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 48                     Acra Lending      Jason    Sheridan
# 49               Actian Corporation       Paul     Navarro
#
#                                                 Title  \
# 0                           Manager, Sales Enablement
# 1   Director, Head of Sales Operations and Activat...
# 2                                     Founder and CEO
# 3                            Chief Technology Officer
# 4                                                 COO
# 5   Head of Contact Center Operations, Truckers Ne...
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 8                            Sales Enablement Manager
# 9                           Manager, Sales Operations
# 10         Director of Technology Planning & Delivery
# 11                           Sales Operations Manager
# 12                           Sales Operations Manager
# 13                                      Owner/Founder
# 14                         Revenue Operations Manager
# 15                        Sales Operations Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 18                                President / Partner
# 19                                      Founder / CEO
# 20                            Sr. Integration Manager
# 21                               Salesforce Developer
# 22                   Senior Manager, Sales Operations
# 23              Sales Onboarding & Enablement Manager
# 24                         Sales Operations Team Lead
# 25  Vice President, Head of FINS & Digital Experience
# 26                           Salesforce Administrator
# 27  Manager Insurance Agency Retention Sales Opera...
# 28                                  Western Sales, VP
# 29                    Senior Manager Sales Operations
# 30                           Sales Operations Manager
# 31                           Manager of Sales Support
# 32                       Sales Operations Coordinator
# 33                                 Salesforce Manager
# 34  Corporate Development Advisor - M&A / Corporat...
# 35                                Sales Support Admin
# 36                        Sales Operations Specialist
# 37                Manager, Revenue Operations Systems
# 38                           Salesforce Administrator
# 39  Sr. Director of Salesforce Development and Int...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 42  Global Head, Sales Enablement Services and Rev...
# 43                        Sales Enablement Specialist
# 44                        Sales Operations Specialist
# 45                    Head of Global Sales Operations
# 46  Senior Director of Revenue Programs, Planning ...
# 47       Senior Manager, Revenue Operations, Programs
# 48                    Vice President, Wholesale Sales
# 49                              Support Sales Manager
#
#                                     Email             Phone Mobile  \
# 0           yves.laflamme@1800gotjunk.com   +1 800-468-5865    NaN
# 1                k.schultz@100thieves.com    (424) 298-0196    NaN
# 2                        nick@10kview.com               NaN    NaN
# 3                        matt@10kview.com               NaN    NaN
# 4                       jared@10kview.com               NaN    NaN
# 5           rdearth@160drivingacademy.com    (877) 350-0884    NaN
# 6           david.park@174powerglobal.com   +1 949-748-5970    NaN
# 7        jessica.coscarelli@agilebits.com    (888) 710-9976    NaN
# 8               emily.payne@1password.com    (888) 710-9976    NaN
# 9           charlotte.noordsy@1stdibs.com    (877) 721-3427    NaN
# 10                 rgerami@1worldsync.com    (866) 280-4013    NaN
# 11                    zaratzlaff@2-10.com    (720) 747-6000    NaN
# 12                     zratzlaff@2-10.com    (720) 747-6000    NaN
# 13                  scott@3creekstech.com               NaN    NaN
# 14                    etuohy@3blmedia.com    (866) 508-0993    NaN
# 15             deion.wilson@threestep.com    (781) 722-0338    NaN
# 16                vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                   ggolzari@4refuel.com   +1 888-473-3835    NaN
# 18             rjasinski@5pconsulting.biz   +1 760-652-9127    NaN
# 19               yormond@5pconsulting.biz   +1 760-652-9127    NaN
# 20                 ankit.goyal@6sense.com   +1 415-305-5951    NaN
# 21                     johnson.tai@6st.co  +1(833) 242-6439    NaN
# 22                  helena.ostlin@8x8.com    (844) 716-2409    NaN
# 23               barbara.phillips@8x8.com    (844) 716-2409    NaN
# 24         rgiuffrida@forloversofwood.com   +1 519-653-9322    NaN
# 25                      bmusto@a5corp.com    (844) 226-6344    NaN
# 26                         claire@aaa.com    (800) 222-4357    NaN
# 27             jstassi@aaamidatlantic.com    (800) 222-4357    NaN
# 28                        brianc@aagi.com  +1(888) 442-2886    NaN
# 29               kelli.davis@inovalon.com    (612) 460-4301    NaN
# 30  mengyao.chen@academicpartnerships.com    (214) 210-7300    NaN
# 31                      sdunham@acass.com    (514) 636-1099    NaN
# 32  marcellalvarez@acceleratedsystems.com   +1 519-342-2507    NaN
# 33                 yugandhar.p@accern.com   +1 347-256-8460    NaN
# 34                cbarrios@accesscorp.com    (973) 808-2885    NaN
# 35         jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN
# 36               carla.floyd@atblades.com   +1 800-336-4061    NaN
# 37              tugrul.avci@achievers.com    (888) 622-3343    NaN
# 38         madeline.doyle@acilearning.com    (719) 596-4545    NaN
# 39           cheryl.janda@acilearning.com    (719) 596-4545    NaN
# 40             pedro.lima@acilearning.com    (719) 596-4545    NaN
# 41                vlucero@leaderquest.net    (719) 596-4545    NaN
# 42           bill.mathias@acilearning.com    (719) 596-4545    NaN
# 43        dylan.stenulson@acilearning.com    (719) 596-4545    NaN
# 44        jessica.walters@acilearning.com    (719) 596-4545    NaN
# 45          johan.amador@aciworldwide.com    (844) 776-6605    NaN
# 46                  pam.bragan@acquia.com    (888) 922-7842    NaN
# 47         elizabeth.levasseur@acquia.com    (888) 922-7842    NaN
# 48         jsheridan@citadelservicing.com  +1(888) 800-7661    NaN
# 49                paul.navarro@actian.com    (650) 587-5500    NaN
#
#    Contact Level  Department
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 15           NaN         NaN
# 16           NaN         NaN
# 17           NaN         NaN
# 18           NaN         NaN
# 19           NaN         NaN
# 20           NaN         NaN
# 21           NaN         NaN
# 22           NaN         NaN
# 23           NaN         NaN
# 24           NaN         NaN
# 25           NaN         NaN
# 26           NaN         NaN
# 27           NaN         NaN
# 28           NaN         NaN
# 29           NaN         NaN
# 30           NaN         NaN
# 31           NaN         NaN
# 32           NaN         NaN
# 33           NaN         NaN
# 34           NaN         NaN
# 35           NaN         NaN
# 36           NaN         NaN
# 37           NaN         NaN
# 38           NaN         NaN
# 39           NaN         NaN
# 40           NaN         NaN
# 41           NaN         NaN
# 42           NaN         NaN
# 43           NaN         NaN
# 44           NaN         NaN
# 45           NaN         NaN
# 46           NaN         NaN
# 47           NaN         NaN
# 48           NaN         NaN
# 49           NaN         NaN

# %% [markdown]
# ### (a) C-level Execs
# - Chief Executive Officer to CEO
# - Chief Financial Officer to CFO
# - Chief Operating Officer to COO
# - Chief Sales Officer to CSO
# - Chief Revenue Officer to CRO
# - Chief Marketing Officer to CMO
# - Chief Technology Officer to CTO

# %%
# find & replace full-length strings with abbreviations, ignoring case
df2['Title'] = df2['Title'].str.replace(pat='Chief Executive Officer', repl = 'CEO', flags = re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat='Chief Financial Officer', repl = 'CFO', flags = re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat='Chief Operating Officer', repl = 'COO', flags = re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat='Chief Sales Officer', repl = 'CSO', flags = re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat='Chief Revenue Officer', repl = 'CRO', flags = re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat='Chief Maerketing Officer', repl = 'CMO', flags = re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat='Chief Technology Officer', repl = 'CTO', flags = re.IGNORECASE, regex = True)
df2.head(50)
# Out:
#                        Account Name First Name   Last Name  \
# 0                   1-800-GOT-JUNK?       Yves    Laflamme
# 1                       100 Thieves     Kelsey     Schultz
# 2                               10K       Nick        Hamm
# 3                               10K    Matthew        Lamb
# 4                               10K      Jared      Miller
# 5               160 Driving Academy        Rob      Dearth
# 6                  174 Power Global      David        Park
# 7                         1Password    Jessica  Coscarelli
# 8                         1Password      Emily       Payne
# 9                   1Stdibs.Com Inc  Charlotte     Noordsy
# 10                       1WorldSync      Renee      Gerami
# 11        2-10 Home Buyers Warranty    Zachary    Ratzlaff
# 12        2-10 Home Buyers Warranty       Zach    Ratzlaff
# 13        3 Creeks Technologies LLC      Scott        Aker
# 14                        3BL Media      Emily       Tuohy
# 15                     3STEP Sports      Deion      Wilson
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 18                    5P Consulting      Randy    Jasinski
# 19                    5P Consulting    Y'vonne       Sisco
# 20                           6sense      Ankit       Goyal
# 21                  6Street Digital    Johnson         Tai
# 22                        8x8, Inc.     Helena      Ostlin
# 23                        8x8, Inc.    Barbara    Phillips
# 24               A&M Wood Specialty    Raphael   Giuffrida
# 25                               A5      Bryan       Musto
# 26                    AAA Carolinas     Claire    Crabtree
# 27                AAA Club Alliance       John        Cccm
# 28                             AAGI      Brian        Cook
# 29             Ability Network Inc.      Kelli       Davis
# 30            Academic Partnerships    Mengyao        Chen
# 31                            ACASS     Shauna      Dunham
# 32         Accelerated Systems Inc.    Marcell     Alvarez
# 33                           Accern  Yugandhar           P
# 34  Access | Information Management      Cindy     Barrios
# 35               Access Development       Jodi         Lee
# 36                          AccuTec      Carla       Floyd
# 37                   Achievers Corp    Mustafa        Avci
# 38                     ACI Learning   Madeline       Doyle
# 39                     ACI Learning     Cheryl       Janda
# 40                     ACI Learning      Pedro        Lima
# 41                     ACI Learning       Vito      Lucero
# 42                     ACI Learning    William     Mathias
# 43                     ACI Learning      Dylan   Stenulson
# 44                     ACI Learning    Jessica     Walters
# 45                    ACI Worldwide      Johan      Amador
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 48                     Acra Lending      Jason    Sheridan
# 49               Actian Corporation       Paul     Navarro
#
#                                                 Title  \
# 0                           Manager, Sales Enablement
# 1   Director, Head of Sales Operations and Activat...
# 2                                     Founder and CEO
# 3                                                 CTO
# 4                                                 COO
# 5   Head of Contact Center Operations, Truckers Ne...
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 8                            Sales Enablement Manager
# 9                           Manager, Sales Operations
# 10         Director of Technology Planning & Delivery
# 11                           Sales Operations Manager
# 12                           Sales Operations Manager
# 13                                      Owner/Founder
# 14                         Revenue Operations Manager
# 15                        Sales Operations Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 18                                President / Partner
# 19                                      Founder / CEO
# 20                            Sr. Integration Manager
# 21                               Salesforce Developer
# 22                   Senior Manager, Sales Operations
# 23              Sales Onboarding & Enablement Manager
# 24                         Sales Operations Team Lead
# 25  Vice President, Head of FINS & Digital Experience
# 26                           Salesforce Administrator
# 27  Manager Insurance Agency Retention Sales Opera...
# 28                                  Western Sales, VP
# 29                    Senior Manager Sales Operations
# 30                           Sales Operations Manager
# 31                           Manager of Sales Support
# 32                       Sales Operations Coordinator
# 33                                 Salesforce Manager
# 34  Corporate Development Advisor - M&A / Corporat...
# 35                                Sales Support Admin
# 36                        Sales Operations Specialist
# 37                Manager, Revenue Operations Systems
# 38                           Salesforce Administrator
# 39  Sr. Director of Salesforce Development and Int...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 42  Global Head, Sales Enablement Services and Rev...
# 43                        Sales Enablement Specialist
# 44                        Sales Operations Specialist
# 45                    Head of Global Sales Operations
# 46  Senior Director of Revenue Programs, Planning ...
# 47       Senior Manager, Revenue Operations, Programs
# 48                    Vice President, Wholesale Sales
# 49                              Support Sales Manager
#
#                                     Email             Phone Mobile  \
# 0           yves.laflamme@1800gotjunk.com   +1 800-468-5865    NaN
# 1                k.schultz@100thieves.com    (424) 298-0196    NaN
# 2                        nick@10kview.com               NaN    NaN
# 3                        matt@10kview.com               NaN    NaN
# 4                       jared@10kview.com               NaN    NaN
# 5           rdearth@160drivingacademy.com    (877) 350-0884    NaN
# 6           david.park@174powerglobal.com   +1 949-748-5970    NaN
# 7        jessica.coscarelli@agilebits.com    (888) 710-9976    NaN
# 8               emily.payne@1password.com    (888) 710-9976    NaN
# 9           charlotte.noordsy@1stdibs.com    (877) 721-3427    NaN
# 10                 rgerami@1worldsync.com    (866) 280-4013    NaN
# 11                    zaratzlaff@2-10.com    (720) 747-6000    NaN
# 12                     zratzlaff@2-10.com    (720) 747-6000    NaN
# 13                  scott@3creekstech.com               NaN    NaN
# 14                    etuohy@3blmedia.com    (866) 508-0993    NaN
# 15             deion.wilson@threestep.com    (781) 722-0338    NaN
# 16                vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                   ggolzari@4refuel.com   +1 888-473-3835    NaN
# 18             rjasinski@5pconsulting.biz   +1 760-652-9127    NaN
# 19               yormond@5pconsulting.biz   +1 760-652-9127    NaN
# 20                 ankit.goyal@6sense.com   +1 415-305-5951    NaN
# 21                     johnson.tai@6st.co  +1(833) 242-6439    NaN
# 22                  helena.ostlin@8x8.com    (844) 716-2409    NaN
# 23               barbara.phillips@8x8.com    (844) 716-2409    NaN
# 24         rgiuffrida@forloversofwood.com   +1 519-653-9322    NaN
# 25                      bmusto@a5corp.com    (844) 226-6344    NaN
# 26                         claire@aaa.com    (800) 222-4357    NaN
# 27             jstassi@aaamidatlantic.com    (800) 222-4357    NaN
# 28                        brianc@aagi.com  +1(888) 442-2886    NaN
# 29               kelli.davis@inovalon.com    (612) 460-4301    NaN
# 30  mengyao.chen@academicpartnerships.com    (214) 210-7300    NaN
# 31                      sdunham@acass.com    (514) 636-1099    NaN
# 32  marcellalvarez@acceleratedsystems.com   +1 519-342-2507    NaN
# 33                 yugandhar.p@accern.com   +1 347-256-8460    NaN
# 34                cbarrios@accesscorp.com    (973) 808-2885    NaN
# 35         jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN
# 36               carla.floyd@atblades.com   +1 800-336-4061    NaN
# 37              tugrul.avci@achievers.com    (888) 622-3343    NaN
# 38         madeline.doyle@acilearning.com    (719) 596-4545    NaN
# 39           cheryl.janda@acilearning.com    (719) 596-4545    NaN
# 40             pedro.lima@acilearning.com    (719) 596-4545    NaN
# 41                vlucero@leaderquest.net    (719) 596-4545    NaN
# 42           bill.mathias@acilearning.com    (719) 596-4545    NaN
# 43        dylan.stenulson@acilearning.com    (719) 596-4545    NaN
# 44        jessica.walters@acilearning.com    (719) 596-4545    NaN
# 45          johan.amador@aciworldwide.com    (844) 776-6605    NaN
# 46                  pam.bragan@acquia.com    (888) 922-7842    NaN
# 47         elizabeth.levasseur@acquia.com    (888) 922-7842    NaN
# 48         jsheridan@citadelservicing.com  +1(888) 800-7661    NaN
# 49                paul.navarro@actian.com    (650) 587-5500    NaN
#
#    Contact Level  Department
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 15           NaN         NaN
# 16           NaN         NaN
# 17           NaN         NaN
# 18           NaN         NaN
# 19           NaN         NaN
# 20           NaN         NaN
# 21           NaN         NaN
# 22           NaN         NaN
# 23           NaN         NaN
# 24           NaN         NaN
# 25           NaN         NaN
# 26           NaN         NaN
# 27           NaN         NaN
# 28           NaN         NaN
# 29           NaN         NaN
# 30           NaN         NaN
# 31           NaN         NaN
# 32           NaN         NaN
# 33           NaN         NaN
# 34           NaN         NaN
# 35           NaN         NaN
# 36           NaN         NaN
# 37           NaN         NaN
# 38           NaN         NaN
# 39           NaN         NaN
# 40           NaN         NaN
# 41           NaN         NaN
# 42           NaN         NaN
# 43           NaN         NaN
# 44           NaN         NaN
# 45           NaN         NaN
# 46           NaN         NaN
# 47           NaN         NaN
# 48           NaN         NaN
# 49           NaN         NaN

# %% [markdown]
# ### (b) Management
# - Senior Vice President to SVP
# - Executive Vice President to EVP
# - Assistant Vice President to AVP
# - Associate Vice President to AVP
# - Vice President to VP
# - Financial to Fin’l
# - Senior to Sr.
# - Director to Dir.
# - Manager|Management to Mgr.
# - Corporate to Corp.
# - Division to Div.
# - Executive to Exec.

# %%
# find & replace full-length strings with abbreviations, ignoring case
df2['Title'] = df2['Title'].str.replace(pat='Senior Vice President', repl = 'SVP', flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat='Executive Vice President', repl = 'EVP', flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat='Assistant Vice President', repl = 'AVP', flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat='Associate Vice President', repl = 'AVP', flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat='Vice President', repl = 'VP', flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat='Financial', repl = "Fin'l", flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat="Senior", repl = "Sr.", flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat="Director", repl = "Dir.", flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat="Manager|Management", repl = "Mgr.", flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat="Corporate", repl = "Corp.", flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat="Division", repl = "Div.", flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat="Executive", repl = "Exec.", flags=re.IGNORECASE, regex = True)
df2.head(50)
# Out:
#                        Account Name First Name   Last Name  \
# 0                   1-800-GOT-JUNK?       Yves    Laflamme
# 1                       100 Thieves     Kelsey     Schultz
# 2                               10K       Nick        Hamm
# 3                               10K    Matthew        Lamb
# 4                               10K      Jared      Miller
# 5               160 Driving Academy        Rob      Dearth
# 6                  174 Power Global      David        Park
# 7                         1Password    Jessica  Coscarelli
# 8                         1Password      Emily       Payne
# 9                   1Stdibs.Com Inc  Charlotte     Noordsy
# 10                       1WorldSync      Renee      Gerami
# 11        2-10 Home Buyers Warranty    Zachary    Ratzlaff
# 12        2-10 Home Buyers Warranty       Zach    Ratzlaff
# 13        3 Creeks Technologies LLC      Scott        Aker
# 14                        3BL Media      Emily       Tuohy
# 15                     3STEP Sports      Deion      Wilson
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 18                    5P Consulting      Randy    Jasinski
# 19                    5P Consulting    Y'vonne       Sisco
# 20                           6sense      Ankit       Goyal
# 21                  6Street Digital    Johnson         Tai
# 22                        8x8, Inc.     Helena      Ostlin
# 23                        8x8, Inc.    Barbara    Phillips
# 24               A&M Wood Specialty    Raphael   Giuffrida
# 25                               A5      Bryan       Musto
# 26                    AAA Carolinas     Claire    Crabtree
# 27                AAA Club Alliance       John        Cccm
# 28                             AAGI      Brian        Cook
# 29             Ability Network Inc.      Kelli       Davis
# 30            Academic Partnerships    Mengyao        Chen
# 31                            ACASS     Shauna      Dunham
# 32         Accelerated Systems Inc.    Marcell     Alvarez
# 33                           Accern  Yugandhar           P
# 34  Access | Information Management      Cindy     Barrios
# 35               Access Development       Jodi         Lee
# 36                          AccuTec      Carla       Floyd
# 37                   Achievers Corp    Mustafa        Avci
# 38                     ACI Learning   Madeline       Doyle
# 39                     ACI Learning     Cheryl       Janda
# 40                     ACI Learning      Pedro        Lima
# 41                     ACI Learning       Vito      Lucero
# 42                     ACI Learning    William     Mathias
# 43                     ACI Learning      Dylan   Stenulson
# 44                     ACI Learning    Jessica     Walters
# 45                    ACI Worldwide      Johan      Amador
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 48                     Acra Lending      Jason    Sheridan
# 49               Actian Corporation       Paul     Navarro
#
#                                                 Title  \
# 0                              Mgr., Sales Enablement
# 1      Dir., Head of Sales Operations and Activations
# 2                                     Founder and CEO
# 3                                                 CTO
# 4                                                 COO
# 5   Head of Contact Center Operations, Truckers Ne...
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 8                               Sales Enablement Mgr.
# 9                              Mgr., Sales Operations
# 10             Dir. of Technology Planning & Delivery
# 11                              Sales Operations Mgr.
# 12                              Sales Operations Mgr.
# 13                                      Owner/Founder
# 14                            Revenue Operations Mgr.
# 15                        Sales Operations Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 18                                President / Partner
# 19                                      Founder / CEO
# 20                               Sr. Integration Mgr.
# 21                               Salesforce Developer
# 22                         Sr. Mgr., Sales Operations
# 23                 Sales Onboarding & Enablement Mgr.
# 24                         Sales Operations Team Lead
# 25              VP, Head of FINS & Digital Experience
# 26                           Salesforce Administrator
# 27   Mgr. Insurance Agency Retention Sales Operations
# 28                                  Western Sales, VP
# 29                          Sr. Mgr. Sales Operations
# 30                              Sales Operations Mgr.
# 31                              Mgr. of Sales Support
# 32                       Sales Operations Coordinator
# 33                                    Salesforce Mgr.
# 34  Corp. Development Advisor - M&A / Corp. Partne...
# 35                                Sales Support Admin
# 36                        Sales Operations Specialist
# 37                   Mgr., Revenue Operations Systems
# 38                           Salesforce Administrator
# 39  Sr. Dir. of Salesforce Development and Integra...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 42  Global Head, Sales Enablement Services and Rev...
# 43                        Sales Enablement Specialist
# 44                        Sales Operations Specialist
# 45                    Head of Global Sales Operations
# 46  Sr. Dir. of Revenue Programs, Planning and Inc...
# 47             Sr. Mgr., Revenue Operations, Programs
# 48                                VP, Wholesale Sales
# 49                                 Support Sales Mgr.
#
#                                     Email             Phone Mobile  \
# 0           yves.laflamme@1800gotjunk.com   +1 800-468-5865    NaN
# 1                k.schultz@100thieves.com    (424) 298-0196    NaN
# 2                        nick@10kview.com               NaN    NaN
# 3                        matt@10kview.com               NaN    NaN
# 4                       jared@10kview.com               NaN    NaN
# 5           rdearth@160drivingacademy.com    (877) 350-0884    NaN
# 6           david.park@174powerglobal.com   +1 949-748-5970    NaN
# 7        jessica.coscarelli@agilebits.com    (888) 710-9976    NaN
# 8               emily.payne@1password.com    (888) 710-9976    NaN
# 9           charlotte.noordsy@1stdibs.com    (877) 721-3427    NaN
# 10                 rgerami@1worldsync.com    (866) 280-4013    NaN
# 11                    zaratzlaff@2-10.com    (720) 747-6000    NaN
# 12                     zratzlaff@2-10.com    (720) 747-6000    NaN
# 13                  scott@3creekstech.com               NaN    NaN
# 14                    etuohy@3blmedia.com    (866) 508-0993    NaN
# 15             deion.wilson@threestep.com    (781) 722-0338    NaN
# 16                vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                   ggolzari@4refuel.com   +1 888-473-3835    NaN
# 18             rjasinski@5pconsulting.biz   +1 760-652-9127    NaN
# 19               yormond@5pconsulting.biz   +1 760-652-9127    NaN
# 20                 ankit.goyal@6sense.com   +1 415-305-5951    NaN
# 21                     johnson.tai@6st.co  +1(833) 242-6439    NaN
# 22                  helena.ostlin@8x8.com    (844) 716-2409    NaN
# 23               barbara.phillips@8x8.com    (844) 716-2409    NaN
# 24         rgiuffrida@forloversofwood.com   +1 519-653-9322    NaN
# 25                      bmusto@a5corp.com    (844) 226-6344    NaN
# 26                         claire@aaa.com    (800) 222-4357    NaN
# 27             jstassi@aaamidatlantic.com    (800) 222-4357    NaN
# 28                        brianc@aagi.com  +1(888) 442-2886    NaN
# 29               kelli.davis@inovalon.com    (612) 460-4301    NaN
# 30  mengyao.chen@academicpartnerships.com    (214) 210-7300    NaN
# 31                      sdunham@acass.com    (514) 636-1099    NaN
# 32  marcellalvarez@acceleratedsystems.com   +1 519-342-2507    NaN
# 33                 yugandhar.p@accern.com   +1 347-256-8460    NaN
# 34                cbarrios@accesscorp.com    (973) 808-2885    NaN
# 35         jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN
# 36               carla.floyd@atblades.com   +1 800-336-4061    NaN
# 37              tugrul.avci@achievers.com    (888) 622-3343    NaN
# 38         madeline.doyle@acilearning.com    (719) 596-4545    NaN
# 39           cheryl.janda@acilearning.com    (719) 596-4545    NaN
# 40             pedro.lima@acilearning.com    (719) 596-4545    NaN
# 41                vlucero@leaderquest.net    (719) 596-4545    NaN
# 42           bill.mathias@acilearning.com    (719) 596-4545    NaN
# 43        dylan.stenulson@acilearning.com    (719) 596-4545    NaN
# 44        jessica.walters@acilearning.com    (719) 596-4545    NaN
# 45          johan.amador@aciworldwide.com    (844) 776-6605    NaN
# 46                  pam.bragan@acquia.com    (888) 922-7842    NaN
# 47         elizabeth.levasseur@acquia.com    (888) 922-7842    NaN
# 48         jsheridan@citadelservicing.com  +1(888) 800-7661    NaN
# 49                paul.navarro@actian.com    (650) 587-5500    NaN
#
#    Contact Level  Department
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 15           NaN         NaN
# 16           NaN         NaN
# 17           NaN         NaN
# 18           NaN         NaN
# 19           NaN         NaN
# 20           NaN         NaN
# 21           NaN         NaN
# 22           NaN         NaN
# 23           NaN         NaN
# 24           NaN         NaN
# 25           NaN         NaN
# 26           NaN         NaN
# 27           NaN         NaN
# 28           NaN         NaN
# 29           NaN         NaN
# 30           NaN         NaN
# 31           NaN         NaN
# 32           NaN         NaN
# 33           NaN         NaN
# 34           NaN         NaN
# 35           NaN         NaN
# 36           NaN         NaN
# 37           NaN         NaN
# 38           NaN         NaN
# 39           NaN         NaN
# 40           NaN         NaN
# 41           NaN         NaN
# 42           NaN         NaN
# 43           NaN         NaN
# 44           NaN         NaN
# 45           NaN         NaN
# 46           NaN         NaN
# 47           NaN         NaN
# 48           NaN         NaN
# 49           NaN         NaN

# %% [markdown]
# ### (c) General Conversions
# - Associate to Assoc.
# - Professional to Prof’l
# - Sales Operations to Sales Ops
# - Quality Assurance to QA

# %%
# find & replace full-length strings with abbreviations, ignoring case
df2['Title'] = df2['Title'].str.replace(pat="Associate|Assoc", repl = "Assoc.", flags=re.IGNORECASE, regex = True, )
df2['Title'] = df2['Title'].str.replace(pat="Professional", repl = "Prof'l.", flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat="Sales Operations", repl = "Sales Ops", flags=re.IGNORECASE, regex = True)
df2['Title'] = df2['Title'].str.replace(pat="Quality Assurance", repl = "QA", flags=re.IGNORECASE, regex = True)
df2.head(50)
# Out:
#                        Account Name First Name   Last Name  \
# 0                   1-800-GOT-JUNK?       Yves    Laflamme
# 1                       100 Thieves     Kelsey     Schultz
# 2                               10K       Nick        Hamm
# 3                               10K    Matthew        Lamb
# 4                               10K      Jared      Miller
# 5               160 Driving Academy        Rob      Dearth
# 6                  174 Power Global      David        Park
# 7                         1Password    Jessica  Coscarelli
# 8                         1Password      Emily       Payne
# 9                   1Stdibs.Com Inc  Charlotte     Noordsy
# 10                       1WorldSync      Renee      Gerami
# 11        2-10 Home Buyers Warranty    Zachary    Ratzlaff
# 12        2-10 Home Buyers Warranty       Zach    Ratzlaff
# 13        3 Creeks Technologies LLC      Scott        Aker
# 14                        3BL Media      Emily       Tuohy
# 15                     3STEP Sports      Deion      Wilson
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 18                    5P Consulting      Randy    Jasinski
# 19                    5P Consulting    Y'vonne       Sisco
# 20                           6sense      Ankit       Goyal
# 21                  6Street Digital    Johnson         Tai
# 22                        8x8, Inc.     Helena      Ostlin
# 23                        8x8, Inc.    Barbara    Phillips
# 24               A&M Wood Specialty    Raphael   Giuffrida
# 25                               A5      Bryan       Musto
# 26                    AAA Carolinas     Claire    Crabtree
# 27                AAA Club Alliance       John        Cccm
# 28                             AAGI      Brian        Cook
# 29             Ability Network Inc.      Kelli       Davis
# 30            Academic Partnerships    Mengyao        Chen
# 31                            ACASS     Shauna      Dunham
# 32         Accelerated Systems Inc.    Marcell     Alvarez
# 33                           Accern  Yugandhar           P
# 34  Access | Information Management      Cindy     Barrios
# 35               Access Development       Jodi         Lee
# 36                          AccuTec      Carla       Floyd
# 37                   Achievers Corp    Mustafa        Avci
# 38                     ACI Learning   Madeline       Doyle
# 39                     ACI Learning     Cheryl       Janda
# 40                     ACI Learning      Pedro        Lima
# 41                     ACI Learning       Vito      Lucero
# 42                     ACI Learning    William     Mathias
# 43                     ACI Learning      Dylan   Stenulson
# 44                     ACI Learning    Jessica     Walters
# 45                    ACI Worldwide      Johan      Amador
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 48                     Acra Lending      Jason    Sheridan
# 49               Actian Corporation       Paul     Navarro
#
#                                                 Title  \
# 0                              Mgr., Sales Enablement
# 1             Dir., Head of Sales Ops and Activations
# 2                                     Founder and CEO
# 3                                                 CTO
# 4                                                 COO
# 5   Head of Contact Center Operations, Truckers Ne...
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 8                               Sales Enablement Mgr.
# 9                                     Mgr., Sales Ops
# 10             Dir. of Technology Planning & Delivery
# 11                                     Sales Ops Mgr.
# 12                                     Sales Ops Mgr.
# 13                                      Owner/Founder
# 14                            Revenue Operations Mgr.
# 15                               Sales Ops Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 18                                President / Partner
# 19                                      Founder / CEO
# 20                               Sr. Integration Mgr.
# 21                               Salesforce Developer
# 22                                Sr. Mgr., Sales Ops
# 23                 Sales Onboarding & Enablement Mgr.
# 24                                Sales Ops Team Lead
# 25              VP, Head of FINS & Digital Experience
# 26                           Salesforce Administrator
# 27          Mgr. Insurance Agency Retention Sales Ops
# 28                                  Western Sales, VP
# 29                                 Sr. Mgr. Sales Ops
# 30                                     Sales Ops Mgr.
# 31                              Mgr. of Sales Support
# 32                              Sales Ops Coordinator
# 33                                    Salesforce Mgr.
# 34  Corp. Development Advisor - M&A / Corp. Partne...
# 35                                Sales Support Admin
# 36                               Sales Ops Specialist
# 37                   Mgr., Revenue Operations Systems
# 38                           Salesforce Administrator
# 39  Sr. Dir. of Salesforce Development and Integra...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 42  Global Head, Sales Enablement Services and Rev...
# 43                        Sales Enablement Specialist
# 44                               Sales Ops Specialist
# 45                           Head of Global Sales Ops
# 46  Sr. Dir. of Revenue Programs, Planning and Inc...
# 47             Sr. Mgr., Revenue Operations, Programs
# 48                                VP, Wholesale Sales
# 49                                 Support Sales Mgr.
#
#                                     Email             Phone Mobile  \
# 0           yves.laflamme@1800gotjunk.com   +1 800-468-5865    NaN
# 1                k.schultz@100thieves.com    (424) 298-0196    NaN
# 2                        nick@10kview.com               NaN    NaN
# 3                        matt@10kview.com               NaN    NaN
# 4                       jared@10kview.com               NaN    NaN
# 5           rdearth@160drivingacademy.com    (877) 350-0884    NaN
# 6           david.park@174powerglobal.com   +1 949-748-5970    NaN
# 7        jessica.coscarelli@agilebits.com    (888) 710-9976    NaN
# 8               emily.payne@1password.com    (888) 710-9976    NaN
# 9           charlotte.noordsy@1stdibs.com    (877) 721-3427    NaN
# 10                 rgerami@1worldsync.com    (866) 280-4013    NaN
# 11                    zaratzlaff@2-10.com    (720) 747-6000    NaN
# 12                     zratzlaff@2-10.com    (720) 747-6000    NaN
# 13                  scott@3creekstech.com               NaN    NaN
# 14                    etuohy@3blmedia.com    (866) 508-0993    NaN
# 15             deion.wilson@threestep.com    (781) 722-0338    NaN
# 16                vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                   ggolzari@4refuel.com   +1 888-473-3835    NaN
# 18             rjasinski@5pconsulting.biz   +1 760-652-9127    NaN
# 19               yormond@5pconsulting.biz   +1 760-652-9127    NaN
# 20                 ankit.goyal@6sense.com   +1 415-305-5951    NaN
# 21                     johnson.tai@6st.co  +1(833) 242-6439    NaN
# 22                  helena.ostlin@8x8.com    (844) 716-2409    NaN
# 23               barbara.phillips@8x8.com    (844) 716-2409    NaN
# 24         rgiuffrida@forloversofwood.com   +1 519-653-9322    NaN
# 25                      bmusto@a5corp.com    (844) 226-6344    NaN
# 26                         claire@aaa.com    (800) 222-4357    NaN
# 27             jstassi@aaamidatlantic.com    (800) 222-4357    NaN
# 28                        brianc@aagi.com  +1(888) 442-2886    NaN
# 29               kelli.davis@inovalon.com    (612) 460-4301    NaN
# 30  mengyao.chen@academicpartnerships.com    (214) 210-7300    NaN
# 31                      sdunham@acass.com    (514) 636-1099    NaN
# 32  marcellalvarez@acceleratedsystems.com   +1 519-342-2507    NaN
# 33                 yugandhar.p@accern.com   +1 347-256-8460    NaN
# 34                cbarrios@accesscorp.com    (973) 808-2885    NaN
# 35         jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN
# 36               carla.floyd@atblades.com   +1 800-336-4061    NaN
# 37              tugrul.avci@achievers.com    (888) 622-3343    NaN
# 38         madeline.doyle@acilearning.com    (719) 596-4545    NaN
# 39           cheryl.janda@acilearning.com    (719) 596-4545    NaN
# 40             pedro.lima@acilearning.com    (719) 596-4545    NaN
# 41                vlucero@leaderquest.net    (719) 596-4545    NaN
# 42           bill.mathias@acilearning.com    (719) 596-4545    NaN
# 43        dylan.stenulson@acilearning.com    (719) 596-4545    NaN
# 44        jessica.walters@acilearning.com    (719) 596-4545    NaN
# 45          johan.amador@aciworldwide.com    (844) 776-6605    NaN
# 46                  pam.bragan@acquia.com    (888) 922-7842    NaN
# 47         elizabeth.levasseur@acquia.com    (888) 922-7842    NaN
# 48         jsheridan@citadelservicing.com  +1(888) 800-7661    NaN
# 49                paul.navarro@actian.com    (650) 587-5500    NaN
#
#    Contact Level  Department
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 15           NaN         NaN
# 16           NaN         NaN
# 17           NaN         NaN
# 18           NaN         NaN
# 19           NaN         NaN
# 20           NaN         NaN
# 21           NaN         NaN
# 22           NaN         NaN
# 23           NaN         NaN
# 24           NaN         NaN
# 25           NaN         NaN
# 26           NaN         NaN
# 27           NaN         NaN
# 28           NaN         NaN
# 29           NaN         NaN
# 30           NaN         NaN
# 31           NaN         NaN
# 32           NaN         NaN
# 33           NaN         NaN
# 34           NaN         NaN
# 35           NaN         NaN
# 36           NaN         NaN
# 37           NaN         NaN
# 38           NaN         NaN
# 39           NaN         NaN
# 40           NaN         NaN
# 41           NaN         NaN
# 42           NaN         NaN
# 43           NaN         NaN
# 44           NaN         NaN
# 45           NaN         NaN
# 46           NaN         NaN
# 47           NaN         NaN
# 48           NaN         NaN
# 49           NaN         NaN

# %% [markdown]
# ## 2. Categorize 'Contact Level'

# %% [markdown]
# ### (a) Staff
# - Analyst | Analytics
# - Assistant (= last word of title, not Assistant Director, VP, etc.)
# - Associate | Assoc. (= last word of title, not Associate Director, VP, etc.)
# - Executive Assistant
# - Architect
# - Accounts Payable, AP, A/P as sole text in title
# - Accounts Receivable, AR, A/R as sole text in title
# - Administrator, Admin, Administrative
# - Coordinator
# - Representative
# - Clerk
# - Account Executive
# - AE
# - Account Manager
# - Specialist
# - Staff
# - Lead
# - Receptionist
# - Sales Ops as sole text in title
# - Sales Ops Assoc.
# - Sales Ops' as end text
# - Salesforce Assoc.
#
# - 'Developer'
# - 'Support'
# - 'Engineer'
# - 'Planner / Planning'
# - 'Integration'
# - 'Strategist'
# - 'Marketer'
# - 'Instructor'
# - 'Trainer'
# - 'Advisor'
# - 'Trainee'
# - 'QA'
# - 'Scrum Master'
# - 'Recruiter / Recruitment'
# - 'Service Operations'
# - 'Expert'
# - 'Specialist'
# - 'Coach'
# - 'Admin'

# %%
# create condition for containing any of the Staff keywords
staff = (df2['Title'].str.contains(
                                  'Developer|'
                                  'Support|'
                                  'Engineer|'
                                  'Planner|Planning|'
                                  'Integration|'
                                  'Strategist|'
                                  'Marketer|'
                                  'Instructor|'
                                  'Trainer|'
                                  'Advisor|'
                                  'Trainee|'
                                  'QA|'
                                  'Scrum Master|'
                                  'Recruiter|Recruitment|'
                                  'Service Operations|'
                                  'Expert|'
                                  'Specialist|'
                                  'Coach|'
                                  'Admin'
                                  ,na=False, regex=True) |
         df2['Title'].str.contains(r"(?:Analyst|Sales Ops Assoc\.|Salesforce Assoc\.|Analytics|Assistant\n|Assoc\.\n|Executive|Assistant|Architect|Dir\.|\nAccounts Payable\n|\nAP\n|\nA/P\n|\nAccounts Receivable$|\nAR\n|\nA/R\n|Administrator|Admin|Administrative|Coordinator|Representative|Clerk|Account Executive|AE|Account Manager|Specialist|Staff|Lead|Receptionist|Sales Ops$)",na=False, regex=True)
        )

# apply the condition to filter the rows and then set the 'Contact Level' column to 'Staff'
df2.loc[staff, 'Contact Level'] = "Staff"

df2[df2['Contact Level']=='Staff'].head(50)
# Out:
#                              Account Name First Name    Last Name  \
# 1                             100 Thieves     Kelsey      Schultz
# 6                        174 Power Global      David         Park
# 7                               1Password    Jessica   Coscarelli
# 9                         1Stdibs.Com Inc  Charlotte      Noordsy
# 10                             1WorldSync      Renee       Gerami
# 15                           3STEP Sports      Deion       Wilson
# 16                         4Refuel Canada     Victor   Chatellier
# 17                         4Refuel Canada       Goli      Golzari
# 20                                 6sense      Ankit        Goyal
# 21                        6Street Digital    Johnson          Tai
# 22                              8x8, Inc.     Helena       Ostlin
# 24                     A&M Wood Specialty    Raphael    Giuffrida
# 26                          AAA Carolinas     Claire     Crabtree
# 27                      AAA Club Alliance       John         Cccm
# 29                   Ability Network Inc.      Kelli        Davis
# 31                                  ACASS     Shauna       Dunham
# 32               Accelerated Systems Inc.    Marcell      Alvarez
# 34        Access | Information Management      Cindy      Barrios
# 35                     Access Development       Jodi          Lee
# 36                                AccuTec      Carla        Floyd
# 38                           ACI Learning   Madeline        Doyle
# 39                           ACI Learning     Cheryl        Janda
# 40                           ACI Learning      Pedro         Lima
# 41                           ACI Learning       Vito       Lucero
# 43                           ACI Learning      Dylan    Stenulson
# 44                           ACI Learning    Jessica      Walters
# 45                          ACI Worldwide      Johan       Amador
# 46                                 Acquia        Pam       Bragan
# 49                     Actian Corporation       Paul      Navarro
# 50               Active International Ltd      Karen     Cummings
# 52                         ActiveProspect    Shannon       Wiggen
# 54              Activision Blizzard Media    Zachary    Greenberg
# 55              Activision Blizzard, Inc.        Sam        Akiki
# 58                   Acuity International     Jefrey          Joy
# 73                              Acumatica       Jake       Poysti
# 79                             Acumed LLC      Wendy     McIntyre
# 80                           ACV Auctions        Jim       Nassar
# 81                             Acxiom LLC       Dana     Ferguson
# 83             Adelman Travel Group, Inc.      Laura        Schad
# 84                   AdminToArchitect.com     Rafael       Alfaro
# 85                   AdminToArchitect.com    Francis       Pindar
# 87                         Aduro Advisors       Quan          Dao
# 88            Advanced Network Management    Eduardo    Rodriguez
# 89  Advanced Sterilization Products (ASP)        Ali  Balahoroglu
# 90  Advanced Sterilization Products (ASP)     Costas       Bastas
# 91  Advanced Sterilization Products (ASP)      Nikos   Klapadakis
# 92  Advanced Sterilization Products (ASP)   Patrizia     Scarponi
# 94         Advantage Automotive Analytics    Sabrina      Edwards
# 95                       Advocare Company      Jacki      Higgins
# 96                  AE Business Solutions       Matt    Blanchard
#
#                                                 Title  \
# 1             Dir., Head of Sales Ops and Activations
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 9                                     Mgr., Sales Ops
# 10             Dir. of Technology Planning & Delivery
# 15                               Sales Ops Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 20                               Sr. Integration Mgr.
# 21                               Salesforce Developer
# 22                                Sr. Mgr., Sales Ops
# 24                                Sales Ops Team Lead
# 26                           Salesforce Administrator
# 27          Mgr. Insurance Agency Retention Sales Ops
# 29                                 Sr. Mgr. Sales Ops
# 31                              Mgr. of Sales Support
# 32                              Sales Ops Coordinator
# 34  Corp. Development Advisor - M&A / Corp. Partne...
# 35                                Sales Support Admin
# 36                               Sales Ops Specialist
# 38                           Salesforce Administrator
# 39  Sr. Dir. of Salesforce Development and Integra...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 43                        Sales Enablement Specialist
# 44                               Sales Ops Specialist
# 45                           Head of Global Sales Ops
# 46  Sr. Dir. of Revenue Programs, Planning and Inc...
# 49                                 Support Sales Mgr.
# 50                                       VP Sales Ops
# 52                         Dir. of Revenue Operations
# 54                                 Sr. Mgr. Sales Ops
# 55                               Salesforce Developer
# 58  Sr. Salesforce Administrator / SF Team Support...
# 73             Mgr., Data Analytics and Visualization
# 79                                 Sr. Mgr. Sales Ops
# 80                                 Sr. Mgr. Sales Ops
# 81                          Sr. Mgr. of Sales Support
# 83                                Mgr., Sales Support
# 84    Studying for Salesforce Certified Administrator
# 85  Salesforce Architect & Coach to 100k+ Salesfor...
# 87                     Salesforce Solutions Developer
# 88  Dir. of Salesforce and Business Analytics Prac...
# 89  Distribution and Sales Support Mgr. Turkey&Aze...
# 90                      Sales Rep / Technical Support
# 91         Sales Representative and Technical Support
# 92                    Sales Force Contractual Support
# 94                                  Dir. of Sales Ops
# 95                        Nutrition & Fitness Advisor
# 96                  Dir. of Sales Ops - West District
#
#                                      Email             Phone Mobile  \
# 1                 k.schultz@100thieves.com    (424) 298-0196    NaN
# 6            david.park@174powerglobal.com   +1 949-748-5970    NaN
# 7         jessica.coscarelli@agilebits.com    (888) 710-9976    NaN
# 9            charlotte.noordsy@1stdibs.com    (877) 721-3427    NaN
# 10                  rgerami@1worldsync.com    (866) 280-4013    NaN
# 15              deion.wilson@threestep.com    (781) 722-0338    NaN
# 16                 vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                    ggolzari@4refuel.com   +1 888-473-3835    NaN
# 20                  ankit.goyal@6sense.com   +1 415-305-5951    NaN
# 21                      johnson.tai@6st.co  +1(833) 242-6439    NaN
# 22                   helena.ostlin@8x8.com    (844) 716-2409    NaN
# 24          rgiuffrida@forloversofwood.com   +1 519-653-9322    NaN
# 26                          claire@aaa.com    (800) 222-4357    NaN
# 27              jstassi@aaamidatlantic.com    (800) 222-4357    NaN
# 29                kelli.davis@inovalon.com    (612) 460-4301    NaN
# 31                       sdunham@acass.com    (514) 636-1099    NaN
# 32   marcellalvarez@acceleratedsystems.com   +1 519-342-2507    NaN
# 34                 cbarrios@accesscorp.com    (973) 808-2885    NaN
# 35          jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN
# 36                carla.floyd@atblades.com   +1 800-336-4061    NaN
# 38          madeline.doyle@acilearning.com    (719) 596-4545    NaN
# 39            cheryl.janda@acilearning.com    (719) 596-4545    NaN
# 40              pedro.lima@acilearning.com    (719) 596-4545    NaN
# 41                 vlucero@leaderquest.net    (719) 596-4545    NaN
# 43         dylan.stenulson@acilearning.com    (719) 596-4545    NaN
# 44         jessica.walters@acilearning.com    (719) 596-4545    NaN
# 45           johan.amador@aciworldwide.com    (844) 776-6605    NaN
# 46                   pam.bragan@acquia.com    (888) 922-7842    NaN
# 49                 paul.navarro@actian.com    (650) 587-5500    NaN
# 50  karen.cummings@activeinternational.com    (845) 732-8806    NaN
# 52       shannon.wiggen@activeprospect.com    (888) 624-4159    NaN
# 54        zachary.greenberg@activision.com    (310) 255-2000    NaN
# 55            oussama.akiki@activision.com   +1-310-255-2000    NaN
# 58      jefrey.joy@acuityinternational.com    (703) 261-1110    NaN
# 73               jake.poysti@acumatica.com   +1 888-228-8300    NaN
# 79               wendy.mcintyre@acumed.net    (503) 627-9957    NaN
# 80                 jnassar@acvauctions.com    (800) 553-4070    NaN
# 81               dana.blackburn@acxiom.com    (866) 352-3267    NaN
# 83                lschad@adelmantravel.com   +1 414-410-8300    NaN
# 84             rafael@admintoarchitect.com               NaN    NaN
# 85            francis@admintoarchitect.com               NaN    NaN
# 87                  quan@aduroadvisors.com   +1 650 690 2060    NaN
# 88               eduardo.rodriguez@anm.com    (877) 266-8822    NaN
# 89                 ali.balahoroglu@asp.com  //1-888-783-7723    NaN
# 90                   costas.bastas@asp.com  //1-888-783-7723    NaN
# 91                nikos.klapadakis@asp.com  //1-888-783-7723    NaN
# 92               patrizia.scarponi@asp.com  //1-888-783-7723    NaN
# 94               sedwards@advantagegps.com        8005537031    NaN
# 95                       jhiggins@tams.com     0131 472 4792    NaN
# 96                 matt.blanchard@aebs.com    (608) 395-2900    NaN
#
#    Contact Level  Department
# 1          Staff         NaN
# 6          Staff         NaN
# 7          Staff         NaN
# 9          Staff         NaN
# 10         Staff         NaN
# 15         Staff         NaN
# 16         Staff         NaN
# 17         Staff         NaN
# 20         Staff         NaN
# 21         Staff         NaN
# 22         Staff         NaN
# 24         Staff         NaN
# 26         Staff         NaN
# 27         Staff         NaN
# 29         Staff         NaN
# 31         Staff         NaN
# 32         Staff         NaN
# 34         Staff         NaN
# 35         Staff         NaN
# 36         Staff         NaN
# 38         Staff         NaN
# 39         Staff         NaN
# 40         Staff         NaN
# 41         Staff         NaN
# 43         Staff         NaN
# 44         Staff         NaN
# 45         Staff         NaN
# 46         Staff         NaN
# 49         Staff         NaN
# 50         Staff         NaN
# 52         Staff         NaN
# 54         Staff         NaN
# 55         Staff         NaN
# 58         Staff         NaN
# 73         Staff         NaN
# 79         Staff         NaN
# 80         Staff         NaN
# 81         Staff         NaN
# 83         Staff         NaN
# 84         Staff         NaN
# 85         Staff         NaN
# 87         Staff         NaN
# 88         Staff         NaN
# 89         Staff         NaN
# 90         Staff         NaN
# 91         Staff         NaN
# 92         Staff         NaN
# 94         Staff         NaN
# 95         Staff         NaN
# 96         Staff         NaN

# %% [markdown]
# ### (b) Management
# - SVP
# - EVP
# - AVP
# - VP
# - Controller
# - Dir.
# - Mgr. (except Account Mgr.)
# - Supervisor
# - Division
# - Executive
# - Head
# - Branch Mgr.
# - Partner

# %%
# filter dataframe by Management titles, then set the 'Contact Level' columns equal to 'Management'
# SYNTAX: df.loc[df[‘filter column’] condition, ‘target column name’] = ‘target column value if condition is met’
# negative lookbehind assertion to exclude Account Mgr.
# end of line backslashes to escape line created wrap issues for easy reading, used quotes for each line instead
df2.loc[df2['Title'].str.contains(
                                  'SVP|EVP|AVP|VP|'
                                  'Controller|'
                                  'Dir\.|'
                                  '(?<!Account )Mgr\.|'
                                  'Supervisor|'
                                  'Division|'
                                  'Executive|'
                                  'Head|'
                                  'Branch Mgr\.|'
                                  'Partner',
                                  na=False, regex=True),'Contact Level'] = 'Management'

df2.head(50)
# Out:
#                        Account Name First Name   Last Name  \
# 0                   1-800-GOT-JUNK?       Yves    Laflamme
# 1                       100 Thieves     Kelsey     Schultz
# 2                               10K       Nick        Hamm
# 3                               10K    Matthew        Lamb
# 4                               10K      Jared      Miller
# 5               160 Driving Academy        Rob      Dearth
# 6                  174 Power Global      David        Park
# 7                         1Password    Jessica  Coscarelli
# 8                         1Password      Emily       Payne
# 9                   1Stdibs.Com Inc  Charlotte     Noordsy
# 10                       1WorldSync      Renee      Gerami
# 11        2-10 Home Buyers Warranty    Zachary    Ratzlaff
# 12        2-10 Home Buyers Warranty       Zach    Ratzlaff
# 13        3 Creeks Technologies LLC      Scott        Aker
# 14                        3BL Media      Emily       Tuohy
# 15                     3STEP Sports      Deion      Wilson
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 18                    5P Consulting      Randy    Jasinski
# 19                    5P Consulting    Y'vonne       Sisco
# 20                           6sense      Ankit       Goyal
# 21                  6Street Digital    Johnson         Tai
# 22                        8x8, Inc.     Helena      Ostlin
# 23                        8x8, Inc.    Barbara    Phillips
# 24               A&M Wood Specialty    Raphael   Giuffrida
# 25                               A5      Bryan       Musto
# 26                    AAA Carolinas     Claire    Crabtree
# 27                AAA Club Alliance       John        Cccm
# 28                             AAGI      Brian        Cook
# 29             Ability Network Inc.      Kelli       Davis
# 30            Academic Partnerships    Mengyao        Chen
# 31                            ACASS     Shauna      Dunham
# 32         Accelerated Systems Inc.    Marcell     Alvarez
# 33                           Accern  Yugandhar           P
# 34  Access | Information Management      Cindy     Barrios
# 35               Access Development       Jodi         Lee
# 36                          AccuTec      Carla       Floyd
# 37                   Achievers Corp    Mustafa        Avci
# 38                     ACI Learning   Madeline       Doyle
# 39                     ACI Learning     Cheryl       Janda
# 40                     ACI Learning      Pedro        Lima
# 41                     ACI Learning       Vito      Lucero
# 42                     ACI Learning    William     Mathias
# 43                     ACI Learning      Dylan   Stenulson
# 44                     ACI Learning    Jessica     Walters
# 45                    ACI Worldwide      Johan      Amador
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 48                     Acra Lending      Jason    Sheridan
# 49               Actian Corporation       Paul     Navarro
#
#                                                 Title  \
# 0                              Mgr., Sales Enablement
# 1             Dir., Head of Sales Ops and Activations
# 2                                     Founder and CEO
# 3                                                 CTO
# 4                                                 COO
# 5   Head of Contact Center Operations, Truckers Ne...
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 8                               Sales Enablement Mgr.
# 9                                     Mgr., Sales Ops
# 10             Dir. of Technology Planning & Delivery
# 11                                     Sales Ops Mgr.
# 12                                     Sales Ops Mgr.
# 13                                      Owner/Founder
# 14                            Revenue Operations Mgr.
# 15                               Sales Ops Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 18                                President / Partner
# 19                                      Founder / CEO
# 20                               Sr. Integration Mgr.
# 21                               Salesforce Developer
# 22                                Sr. Mgr., Sales Ops
# 23                 Sales Onboarding & Enablement Mgr.
# 24                                Sales Ops Team Lead
# 25              VP, Head of FINS & Digital Experience
# 26                           Salesforce Administrator
# 27          Mgr. Insurance Agency Retention Sales Ops
# 28                                  Western Sales, VP
# 29                                 Sr. Mgr. Sales Ops
# 30                                     Sales Ops Mgr.
# 31                              Mgr. of Sales Support
# 32                              Sales Ops Coordinator
# 33                                    Salesforce Mgr.
# 34  Corp. Development Advisor - M&A / Corp. Partne...
# 35                                Sales Support Admin
# 36                               Sales Ops Specialist
# 37                   Mgr., Revenue Operations Systems
# 38                           Salesforce Administrator
# 39  Sr. Dir. of Salesforce Development and Integra...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 42  Global Head, Sales Enablement Services and Rev...
# 43                        Sales Enablement Specialist
# 44                               Sales Ops Specialist
# 45                           Head of Global Sales Ops
# 46  Sr. Dir. of Revenue Programs, Planning and Inc...
# 47             Sr. Mgr., Revenue Operations, Programs
# 48                                VP, Wholesale Sales
# 49                                 Support Sales Mgr.
#
#                                     Email             Phone Mobile  \
# 0           yves.laflamme@1800gotjunk.com   +1 800-468-5865    NaN
# 1                k.schultz@100thieves.com    (424) 298-0196    NaN
# 2                        nick@10kview.com               NaN    NaN
# 3                        matt@10kview.com               NaN    NaN
# 4                       jared@10kview.com               NaN    NaN
# 5           rdearth@160drivingacademy.com    (877) 350-0884    NaN
# 6           david.park@174powerglobal.com   +1 949-748-5970    NaN
# 7        jessica.coscarelli@agilebits.com    (888) 710-9976    NaN
# 8               emily.payne@1password.com    (888) 710-9976    NaN
# 9           charlotte.noordsy@1stdibs.com    (877) 721-3427    NaN
# 10                 rgerami@1worldsync.com    (866) 280-4013    NaN
# 11                    zaratzlaff@2-10.com    (720) 747-6000    NaN
# 12                     zratzlaff@2-10.com    (720) 747-6000    NaN
# 13                  scott@3creekstech.com               NaN    NaN
# 14                    etuohy@3blmedia.com    (866) 508-0993    NaN
# 15             deion.wilson@threestep.com    (781) 722-0338    NaN
# 16                vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                   ggolzari@4refuel.com   +1 888-473-3835    NaN
# 18             rjasinski@5pconsulting.biz   +1 760-652-9127    NaN
# 19               yormond@5pconsulting.biz   +1 760-652-9127    NaN
# 20                 ankit.goyal@6sense.com   +1 415-305-5951    NaN
# 21                     johnson.tai@6st.co  +1(833) 242-6439    NaN
# 22                  helena.ostlin@8x8.com    (844) 716-2409    NaN
# 23               barbara.phillips@8x8.com    (844) 716-2409    NaN
# 24         rgiuffrida@forloversofwood.com   +1 519-653-9322    NaN
# 25                      bmusto@a5corp.com    (844) 226-6344    NaN
# 26                         claire@aaa.com    (800) 222-4357    NaN
# 27             jstassi@aaamidatlantic.com    (800) 222-4357    NaN
# 28                        brianc@aagi.com  +1(888) 442-2886    NaN
# 29               kelli.davis@inovalon.com    (612) 460-4301    NaN
# 30  mengyao.chen@academicpartnerships.com    (214) 210-7300    NaN
# 31                      sdunham@acass.com    (514) 636-1099    NaN
# 32  marcellalvarez@acceleratedsystems.com   +1 519-342-2507    NaN
# 33                 yugandhar.p@accern.com   +1 347-256-8460    NaN
# 34                cbarrios@accesscorp.com    (973) 808-2885    NaN
# 35         jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN
# 36               carla.floyd@atblades.com   +1 800-336-4061    NaN
# 37              tugrul.avci@achievers.com    (888) 622-3343    NaN
# 38         madeline.doyle@acilearning.com    (719) 596-4545    NaN
# 39           cheryl.janda@acilearning.com    (719) 596-4545    NaN
# 40             pedro.lima@acilearning.com    (719) 596-4545    NaN
# 41                vlucero@leaderquest.net    (719) 596-4545    NaN
# 42           bill.mathias@acilearning.com    (719) 596-4545    NaN
# 43        dylan.stenulson@acilearning.com    (719) 596-4545    NaN
# 44        jessica.walters@acilearning.com    (719) 596-4545    NaN
# 45          johan.amador@aciworldwide.com    (844) 776-6605    NaN
# 46                  pam.bragan@acquia.com    (888) 922-7842    NaN
# 47         elizabeth.levasseur@acquia.com    (888) 922-7842    NaN
# 48         jsheridan@citadelservicing.com  +1(888) 800-7661    NaN
# 49                paul.navarro@actian.com    (650) 587-5500    NaN
#
#    Contact Level  Department
# 0     Management         NaN
# 1     Management         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5     Management         NaN
# 6          Staff         NaN
# 7          Staff         NaN
# 8     Management         NaN
# 9     Management         NaN
# 10    Management         NaN
# 11    Management         NaN
# 12    Management         NaN
# 13           NaN         NaN
# 14    Management         NaN
# 15         Staff         NaN
# 16         Staff         NaN
# 17         Staff         NaN
# 18    Management         NaN
# 19           NaN         NaN
# 20    Management         NaN
# 21         Staff         NaN
# 22    Management         NaN
# 23    Management         NaN
# 24         Staff         NaN
# 25    Management         NaN
# 26         Staff         NaN
# 27    Management         NaN
# 28    Management         NaN
# 29    Management         NaN
# 30    Management         NaN
# 31    Management         NaN
# 32         Staff         NaN
# 33    Management         NaN
# 34    Management         NaN
# 35         Staff         NaN
# 36         Staff         NaN
# 37    Management         NaN
# 38         Staff         NaN
# 39    Management         NaN
# 40         Staff         NaN
# 41         Staff         NaN
# 42    Management         NaN
# 43         Staff         NaN
# 44         Staff         NaN
# 45    Management         NaN
# 46    Management         NaN
# 47    Management         NaN
# 48    Management         NaN
# 49    Management         NaN

# %% [markdown]
# ### (c) CXO
# - CFO
# - COO
# - CAO
# - CSO
# - CRO
# - CMO
# - CTO
# - titles containing Board, Chair

# %%
# filter dataframe by Chief Officer titles, then set the 'Contact Level' columns equal to 'CXO'
# SYNTAX: df.loc[df[‘filter column’] condition, ‘target column name’] = ‘target column value if condition is met’
# backslashes for splitting expressions into multiple lines
# ADDED 'CTO'
df2.loc[df2['Title'].str.contains(\
                                              'CFO|COO|CAO|CSO|CRO|CMO|CTO|\bBoard\b|\bChair\b',\
                                              na=False, regex=True),'Contact Level']\
                                              = 'CXO'

df2.head(50)
# Out:
#                        Account Name First Name   Last Name  \
# 0                   1-800-GOT-JUNK?       Yves    Laflamme
# 1                       100 Thieves     Kelsey     Schultz
# 2                               10K       Nick        Hamm
# 3                               10K    Matthew        Lamb
# 4                               10K      Jared      Miller
# 5               160 Driving Academy        Rob      Dearth
# 6                  174 Power Global      David        Park
# 7                         1Password    Jessica  Coscarelli
# 8                         1Password      Emily       Payne
# 9                   1Stdibs.Com Inc  Charlotte     Noordsy
# 10                       1WorldSync      Renee      Gerami
# 11        2-10 Home Buyers Warranty    Zachary    Ratzlaff
# 12        2-10 Home Buyers Warranty       Zach    Ratzlaff
# 13        3 Creeks Technologies LLC      Scott        Aker
# 14                        3BL Media      Emily       Tuohy
# 15                     3STEP Sports      Deion      Wilson
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 18                    5P Consulting      Randy    Jasinski
# 19                    5P Consulting    Y'vonne       Sisco
# 20                           6sense      Ankit       Goyal
# 21                  6Street Digital    Johnson         Tai
# 22                        8x8, Inc.     Helena      Ostlin
# 23                        8x8, Inc.    Barbara    Phillips
# 24               A&M Wood Specialty    Raphael   Giuffrida
# 25                               A5      Bryan       Musto
# 26                    AAA Carolinas     Claire    Crabtree
# 27                AAA Club Alliance       John        Cccm
# 28                             AAGI      Brian        Cook
# 29             Ability Network Inc.      Kelli       Davis
# 30            Academic Partnerships    Mengyao        Chen
# 31                            ACASS     Shauna      Dunham
# 32         Accelerated Systems Inc.    Marcell     Alvarez
# 33                           Accern  Yugandhar           P
# 34  Access | Information Management      Cindy     Barrios
# 35               Access Development       Jodi         Lee
# 36                          AccuTec      Carla       Floyd
# 37                   Achievers Corp    Mustafa        Avci
# 38                     ACI Learning   Madeline       Doyle
# 39                     ACI Learning     Cheryl       Janda
# 40                     ACI Learning      Pedro        Lima
# 41                     ACI Learning       Vito      Lucero
# 42                     ACI Learning    William     Mathias
# 43                     ACI Learning      Dylan   Stenulson
# 44                     ACI Learning    Jessica     Walters
# 45                    ACI Worldwide      Johan      Amador
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 48                     Acra Lending      Jason    Sheridan
# 49               Actian Corporation       Paul     Navarro
#
#                                                 Title  \
# 0                              Mgr., Sales Enablement
# 1             Dir., Head of Sales Ops and Activations
# 2                                     Founder and CEO
# 3                                                 CTO
# 4                                                 COO
# 5   Head of Contact Center Operations, Truckers Ne...
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 8                               Sales Enablement Mgr.
# 9                                     Mgr., Sales Ops
# 10             Dir. of Technology Planning & Delivery
# 11                                     Sales Ops Mgr.
# 12                                     Sales Ops Mgr.
# 13                                      Owner/Founder
# 14                            Revenue Operations Mgr.
# 15                               Sales Ops Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 18                                President / Partner
# 19                                      Founder / CEO
# 20                               Sr. Integration Mgr.
# 21                               Salesforce Developer
# 22                                Sr. Mgr., Sales Ops
# 23                 Sales Onboarding & Enablement Mgr.
# 24                                Sales Ops Team Lead
# 25              VP, Head of FINS & Digital Experience
# 26                           Salesforce Administrator
# 27          Mgr. Insurance Agency Retention Sales Ops
# 28                                  Western Sales, VP
# 29                                 Sr. Mgr. Sales Ops
# 30                                     Sales Ops Mgr.
# 31                              Mgr. of Sales Support
# 32                              Sales Ops Coordinator
# 33                                    Salesforce Mgr.
# 34  Corp. Development Advisor - M&A / Corp. Partne...
# 35                                Sales Support Admin
# 36                               Sales Ops Specialist
# 37                   Mgr., Revenue Operations Systems
# 38                           Salesforce Administrator
# 39  Sr. Dir. of Salesforce Development and Integra...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 42  Global Head, Sales Enablement Services and Rev...
# 43                        Sales Enablement Specialist
# 44                               Sales Ops Specialist
# 45                           Head of Global Sales Ops
# 46  Sr. Dir. of Revenue Programs, Planning and Inc...
# 47             Sr. Mgr., Revenue Operations, Programs
# 48                                VP, Wholesale Sales
# 49                                 Support Sales Mgr.
#
#                                     Email             Phone Mobile  \
# 0           yves.laflamme@1800gotjunk.com   +1 800-468-5865    NaN
# 1                k.schultz@100thieves.com    (424) 298-0196    NaN
# 2                        nick@10kview.com               NaN    NaN
# 3                        matt@10kview.com               NaN    NaN
# 4                       jared@10kview.com               NaN    NaN
# 5           rdearth@160drivingacademy.com    (877) 350-0884    NaN
# 6           david.park@174powerglobal.com   +1 949-748-5970    NaN
# 7        jessica.coscarelli@agilebits.com    (888) 710-9976    NaN
# 8               emily.payne@1password.com    (888) 710-9976    NaN
# 9           charlotte.noordsy@1stdibs.com    (877) 721-3427    NaN
# 10                 rgerami@1worldsync.com    (866) 280-4013    NaN
# 11                    zaratzlaff@2-10.com    (720) 747-6000    NaN
# 12                     zratzlaff@2-10.com    (720) 747-6000    NaN
# 13                  scott@3creekstech.com               NaN    NaN
# 14                    etuohy@3blmedia.com    (866) 508-0993    NaN
# 15             deion.wilson@threestep.com    (781) 722-0338    NaN
# 16                vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                   ggolzari@4refuel.com   +1 888-473-3835    NaN
# 18             rjasinski@5pconsulting.biz   +1 760-652-9127    NaN
# 19               yormond@5pconsulting.biz   +1 760-652-9127    NaN
# 20                 ankit.goyal@6sense.com   +1 415-305-5951    NaN
# 21                     johnson.tai@6st.co  +1(833) 242-6439    NaN
# 22                  helena.ostlin@8x8.com    (844) 716-2409    NaN
# 23               barbara.phillips@8x8.com    (844) 716-2409    NaN
# 24         rgiuffrida@forloversofwood.com   +1 519-653-9322    NaN
# 25                      bmusto@a5corp.com    (844) 226-6344    NaN
# 26                         claire@aaa.com    (800) 222-4357    NaN
# 27             jstassi@aaamidatlantic.com    (800) 222-4357    NaN
# 28                        brianc@aagi.com  +1(888) 442-2886    NaN
# 29               kelli.davis@inovalon.com    (612) 460-4301    NaN
# 30  mengyao.chen@academicpartnerships.com    (214) 210-7300    NaN
# 31                      sdunham@acass.com    (514) 636-1099    NaN
# 32  marcellalvarez@acceleratedsystems.com   +1 519-342-2507    NaN
# 33                 yugandhar.p@accern.com   +1 347-256-8460    NaN
# 34                cbarrios@accesscorp.com    (973) 808-2885    NaN
# 35         jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN
# 36               carla.floyd@atblades.com   +1 800-336-4061    NaN
# 37              tugrul.avci@achievers.com    (888) 622-3343    NaN
# 38         madeline.doyle@acilearning.com    (719) 596-4545    NaN
# 39           cheryl.janda@acilearning.com    (719) 596-4545    NaN
# 40             pedro.lima@acilearning.com    (719) 596-4545    NaN
# 41                vlucero@leaderquest.net    (719) 596-4545    NaN
# 42           bill.mathias@acilearning.com    (719) 596-4545    NaN
# 43        dylan.stenulson@acilearning.com    (719) 596-4545    NaN
# 44        jessica.walters@acilearning.com    (719) 596-4545    NaN
# 45          johan.amador@aciworldwide.com    (844) 776-6605    NaN
# 46                  pam.bragan@acquia.com    (888) 922-7842    NaN
# 47         elizabeth.levasseur@acquia.com    (888) 922-7842    NaN
# 48         jsheridan@citadelservicing.com  +1(888) 800-7661    NaN
# 49                paul.navarro@actian.com    (650) 587-5500    NaN
#
#    Contact Level  Department
# 0     Management         NaN
# 1     Management         NaN
# 2            NaN         NaN
# 3            CXO         NaN
# 4            CXO         NaN
# 5     Management         NaN
# 6          Staff         NaN
# 7          Staff         NaN
# 8     Management         NaN
# 9     Management         NaN
# 10    Management         NaN
# 11    Management         NaN
# 12    Management         NaN
# 13           NaN         NaN
# 14    Management         NaN
# 15         Staff         NaN
# 16         Staff         NaN
# 17         Staff         NaN
# 18    Management         NaN
# 19           NaN         NaN
# 20    Management         NaN
# 21         Staff         NaN
# 22    Management         NaN
# 23    Management         NaN
# 24         Staff         NaN
# 25    Management         NaN
# 26         Staff         NaN
# 27    Management         NaN
# 28    Management         NaN
# 29    Management         NaN
# 30    Management         NaN
# 31    Management         NaN
# 32         Staff         NaN
# 33    Management         NaN
# 34    Management         NaN
# 35         Staff         NaN
# 36         Staff         NaN
# 37    Management         NaN
# 38         Staff         NaN
# 39    Management         NaN
# 40         Staff         NaN
# 41         Staff         NaN
# 42    Management         NaN
# 43         Staff         NaN
# 44         Staff         NaN
# 45    Management         NaN
# 46    Management         NaN
# 47    Management         NaN
# 48    Management         NaN
# 49    Management         NaN

# %% [markdown]
# ### (d) Executive
# - CEO
# - President
# - Founder
# - Co-founder
# - Owner

# %%
# filter dataframe by Executive titles, then set the 'Contact Level' columns equal to 'Executive'
# SYNTAX: df.loc[df[‘filter column’] condition, ‘target column name’] = ‘target column value if condition is met’
df2.loc[df2['Title'].str.contains('CEO|President|Founder|Co-Founder|Co-founder|Owner', na=False),'Contact Level'] = 'Executive'

df2.head(50)
# Out:
#                        Account Name First Name   Last Name  \
# 0                   1-800-GOT-JUNK?       Yves    Laflamme
# 1                       100 Thieves     Kelsey     Schultz
# 2                               10K       Nick        Hamm
# 3                               10K    Matthew        Lamb
# 4                               10K      Jared      Miller
# 5               160 Driving Academy        Rob      Dearth
# 6                  174 Power Global      David        Park
# 7                         1Password    Jessica  Coscarelli
# 8                         1Password      Emily       Payne
# 9                   1Stdibs.Com Inc  Charlotte     Noordsy
# 10                       1WorldSync      Renee      Gerami
# 11        2-10 Home Buyers Warranty    Zachary    Ratzlaff
# 12        2-10 Home Buyers Warranty       Zach    Ratzlaff
# 13        3 Creeks Technologies LLC      Scott        Aker
# 14                        3BL Media      Emily       Tuohy
# 15                     3STEP Sports      Deion      Wilson
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 18                    5P Consulting      Randy    Jasinski
# 19                    5P Consulting    Y'vonne       Sisco
# 20                           6sense      Ankit       Goyal
# 21                  6Street Digital    Johnson         Tai
# 22                        8x8, Inc.     Helena      Ostlin
# 23                        8x8, Inc.    Barbara    Phillips
# 24               A&M Wood Specialty    Raphael   Giuffrida
# 25                               A5      Bryan       Musto
# 26                    AAA Carolinas     Claire    Crabtree
# 27                AAA Club Alliance       John        Cccm
# 28                             AAGI      Brian        Cook
# 29             Ability Network Inc.      Kelli       Davis
# 30            Academic Partnerships    Mengyao        Chen
# 31                            ACASS     Shauna      Dunham
# 32         Accelerated Systems Inc.    Marcell     Alvarez
# 33                           Accern  Yugandhar           P
# 34  Access | Information Management      Cindy     Barrios
# 35               Access Development       Jodi         Lee
# 36                          AccuTec      Carla       Floyd
# 37                   Achievers Corp    Mustafa        Avci
# 38                     ACI Learning   Madeline       Doyle
# 39                     ACI Learning     Cheryl       Janda
# 40                     ACI Learning      Pedro        Lima
# 41                     ACI Learning       Vito      Lucero
# 42                     ACI Learning    William     Mathias
# 43                     ACI Learning      Dylan   Stenulson
# 44                     ACI Learning    Jessica     Walters
# 45                    ACI Worldwide      Johan      Amador
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 48                     Acra Lending      Jason    Sheridan
# 49               Actian Corporation       Paul     Navarro
#
#                                                 Title  \
# 0                              Mgr., Sales Enablement
# 1             Dir., Head of Sales Ops and Activations
# 2                                     Founder and CEO
# 3                                                 CTO
# 4                                                 COO
# 5   Head of Contact Center Operations, Truckers Ne...
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 8                               Sales Enablement Mgr.
# 9                                     Mgr., Sales Ops
# 10             Dir. of Technology Planning & Delivery
# 11                                     Sales Ops Mgr.
# 12                                     Sales Ops Mgr.
# 13                                      Owner/Founder
# 14                            Revenue Operations Mgr.
# 15                               Sales Ops Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 18                                President / Partner
# 19                                      Founder / CEO
# 20                               Sr. Integration Mgr.
# 21                               Salesforce Developer
# 22                                Sr. Mgr., Sales Ops
# 23                 Sales Onboarding & Enablement Mgr.
# 24                                Sales Ops Team Lead
# 25              VP, Head of FINS & Digital Experience
# 26                           Salesforce Administrator
# 27          Mgr. Insurance Agency Retention Sales Ops
# 28                                  Western Sales, VP
# 29                                 Sr. Mgr. Sales Ops
# 30                                     Sales Ops Mgr.
# 31                              Mgr. of Sales Support
# 32                              Sales Ops Coordinator
# 33                                    Salesforce Mgr.
# 34  Corp. Development Advisor - M&A / Corp. Partne...
# 35                                Sales Support Admin
# 36                               Sales Ops Specialist
# 37                   Mgr., Revenue Operations Systems
# 38                           Salesforce Administrator
# 39  Sr. Dir. of Salesforce Development and Integra...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 42  Global Head, Sales Enablement Services and Rev...
# 43                        Sales Enablement Specialist
# 44                               Sales Ops Specialist
# 45                           Head of Global Sales Ops
# 46  Sr. Dir. of Revenue Programs, Planning and Inc...
# 47             Sr. Mgr., Revenue Operations, Programs
# 48                                VP, Wholesale Sales
# 49                                 Support Sales Mgr.
#
#                                     Email             Phone Mobile  \
# 0           yves.laflamme@1800gotjunk.com   +1 800-468-5865    NaN
# 1                k.schultz@100thieves.com    (424) 298-0196    NaN
# 2                        nick@10kview.com               NaN    NaN
# 3                        matt@10kview.com               NaN    NaN
# 4                       jared@10kview.com               NaN    NaN
# 5           rdearth@160drivingacademy.com    (877) 350-0884    NaN
# 6           david.park@174powerglobal.com   +1 949-748-5970    NaN
# 7        jessica.coscarelli@agilebits.com    (888) 710-9976    NaN
# 8               emily.payne@1password.com    (888) 710-9976    NaN
# 9           charlotte.noordsy@1stdibs.com    (877) 721-3427    NaN
# 10                 rgerami@1worldsync.com    (866) 280-4013    NaN
# 11                    zaratzlaff@2-10.com    (720) 747-6000    NaN
# 12                     zratzlaff@2-10.com    (720) 747-6000    NaN
# 13                  scott@3creekstech.com               NaN    NaN
# 14                    etuohy@3blmedia.com    (866) 508-0993    NaN
# 15             deion.wilson@threestep.com    (781) 722-0338    NaN
# 16                vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                   ggolzari@4refuel.com   +1 888-473-3835    NaN
# 18             rjasinski@5pconsulting.biz   +1 760-652-9127    NaN
# 19               yormond@5pconsulting.biz   +1 760-652-9127    NaN
# 20                 ankit.goyal@6sense.com   +1 415-305-5951    NaN
# 21                     johnson.tai@6st.co  +1(833) 242-6439    NaN
# 22                  helena.ostlin@8x8.com    (844) 716-2409    NaN
# 23               barbara.phillips@8x8.com    (844) 716-2409    NaN
# 24         rgiuffrida@forloversofwood.com   +1 519-653-9322    NaN
# 25                      bmusto@a5corp.com    (844) 226-6344    NaN
# 26                         claire@aaa.com    (800) 222-4357    NaN
# 27             jstassi@aaamidatlantic.com    (800) 222-4357    NaN
# 28                        brianc@aagi.com  +1(888) 442-2886    NaN
# 29               kelli.davis@inovalon.com    (612) 460-4301    NaN
# 30  mengyao.chen@academicpartnerships.com    (214) 210-7300    NaN
# 31                      sdunham@acass.com    (514) 636-1099    NaN
# 32  marcellalvarez@acceleratedsystems.com   +1 519-342-2507    NaN
# 33                 yugandhar.p@accern.com   +1 347-256-8460    NaN
# 34                cbarrios@accesscorp.com    (973) 808-2885    NaN
# 35         jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN
# 36               carla.floyd@atblades.com   +1 800-336-4061    NaN
# 37              tugrul.avci@achievers.com    (888) 622-3343    NaN
# 38         madeline.doyle@acilearning.com    (719) 596-4545    NaN
# 39           cheryl.janda@acilearning.com    (719) 596-4545    NaN
# 40             pedro.lima@acilearning.com    (719) 596-4545    NaN
# 41                vlucero@leaderquest.net    (719) 596-4545    NaN
# 42           bill.mathias@acilearning.com    (719) 596-4545    NaN
# 43        dylan.stenulson@acilearning.com    (719) 596-4545    NaN
# 44        jessica.walters@acilearning.com    (719) 596-4545    NaN
# 45          johan.amador@aciworldwide.com    (844) 776-6605    NaN
# 46                  pam.bragan@acquia.com    (888) 922-7842    NaN
# 47         elizabeth.levasseur@acquia.com    (888) 922-7842    NaN
# 48         jsheridan@citadelservicing.com  +1(888) 800-7661    NaN
# 49                paul.navarro@actian.com    (650) 587-5500    NaN
#
#    Contact Level  Department
# 0     Management         NaN
# 1     Management         NaN
# 2      Executive         NaN
# 3            CXO         NaN
# 4            CXO         NaN
# 5     Management         NaN
# 6          Staff         NaN
# 7          Staff         NaN
# 8     Management         NaN
# 9     Management         NaN
# 10    Management         NaN
# 11    Management         NaN
# 12    Management         NaN
# 13     Executive         NaN
# 14    Management         NaN
# 15         Staff         NaN
# 16         Staff         NaN
# 17         Staff         NaN
# 18     Executive         NaN
# 19     Executive         NaN
# 20    Management         NaN
# 21         Staff         NaN
# 22    Management         NaN
# 23    Management         NaN
# 24         Staff         NaN
# 25    Management         NaN
# 26         Staff         NaN
# 27    Management         NaN
# 28    Management         NaN
# 29    Management         NaN
# 30    Management         NaN
# 31    Management         NaN
# 32         Staff         NaN
# 33    Management         NaN
# 34    Management         NaN
# 35         Staff         NaN
# 36         Staff         NaN
# 37    Management         NaN
# 38         Staff         NaN
# 39    Management         NaN
# 40         Staff         NaN
# 41         Staff         NaN
# 42    Management         NaN
# 43         Staff         NaN
# 44         Staff         NaN
# 45    Management         NaN
# 46    Management         NaN
# 47    Management         NaN
# 48    Management         NaN
# 49    Management         NaN

# %%
# See how many Contact Levels are still null (~3.4%)
df2.info()

# 123 titles not given Contact Levels
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4532 entries, 0 to 4531
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Account Name   4532 non-null   object
#  1   First Name     4532 non-null   object
#  2   Last Name      4532 non-null   object
#  3   Title          4532 non-null   object
#  4   Email          4532 non-null   object
#  5   Phone          4391 non-null   object
#  6   Mobile         6 non-null      object
#  7   Contact Level  4422 non-null   object
#  8   Department     0 non-null      float64
# dtypes: float64(1), object(8)
# memory usage: 318.8+ KB

# %%
# group remaining rows by Title to see what is being left out of the categorization (0 in 'Contact Level')
contact_check = df2.groupby('Title').count().sort_values('Account Name', ascending=False)
contact_check[contact_check['Contact Level'] == 0].head(20)
# df2[df2['Title']=='Sales Ops Assoc.']

### FIRST PASS
# # significant numbers (10+)
# 'Developer' (LOTS)
# 'Vp' and any uppercase abbreviation (Ceo, Coo, Svp, Evp) (LOTS)
# 'Assoc.' (LOTS)
# 'Sales Ops'
# 'Support'
# 'Engineer'
# 'Chief Revenue Officer'
# 'Planner'

# # less sigificant (1-10)
# 'Integration'
# 'Integration Lead'
# 'Strategist'
# 'Marketer'
# 'Instructor'
# 'Advisor'
# 'Planner'
# 'Mech.' or 'Mechanic'
# 'Oracle'
# 'Trainee'

### SECOND PASS
# lowercase words that are in categories
# 'Management' instead of 'Manager'
# QA or Quality Assurance
# Analytics instead of 'Analyst'
# Planning
# Sales Ops
# Recruiter or Recruitment
# Scrum Master
# Service Operations
# Expert
# Specialist
# Coach

### THIRD PASS
# 'Sales Ops Assoc.' x14
# 'Sales Ops' x13
# lowercase misses x11+
# Salesforce Assoc. x3
# Mechanic x2
# Sr. Assoc. x2
# Out:
#                                                     Account Name  First Name  \
# Title
# Maintenance Mechanic A                                         3           3
# Oracle                                                         3           3
# Member                                                         2           2
# Sr. Assoc., M&A Transaction Services                           2           2
# Администратор Salesforce                                       2           2
# Assoc. - Venture Capital, Private Equity, and M...             2           2
# Salesforce Functional Configurator                             1           1
# Salesforce Evangelist                                          1           1
# Sales/Revenue Operations and Enablement                        1           1
# Salesforce + Nonprofits                                        1           1
# Salesforce - Business Solutions                                1           1
# Salesforce Commerce Cloud                                      1           1
# Sr. Data Scientist – Data Science a/B Testing                  1           1
# Sr. Assoc.                                                     1           1
# Sr. Assoc., M&A and Strategy                                   1           1
# Solution Tree Assoc. for Priority Schools in a ...             1           1
# Sales Exec.                                                    1           1
# Sales Enablement Assoc.                                        1           1
# Sales Ops - Universe & Clubs                                   1           1
# Valdosta, Taking a BITE!!! Out of HUNGER                       1           1
#
#                                                     Last Name  Email  Phone  \
# Title
# Maintenance Mechanic A                                      3      3      3
# Oracle                                                      3      3      3
# Member                                                      2      2      2
# Sr. Assoc., M&A Transaction Services                        2      2      2
# Администратор Salesforce                                    2      2      2
# Assoc. - Venture Capital, Private Equity, and M...          2      2      2
# Salesforce Functional Configurator                          1      1      1
# Salesforce Evangelist                                       1      1      0
# Sales/Revenue Operations and Enablement                     1      1      1
# Salesforce + Nonprofits                                     1      1      1
# Salesforce - Business Solutions                             1      1      1
# Salesforce Commerce Cloud                                   1      1      1
# Sr. Data Scientist – Data Science a/B Testing               1      1      1
# Sr. Assoc.                                                  1      1      1
# Sr. Assoc., M&A and Strategy                                1      1      1
# Solution Tree Assoc. for Priority Schools in a ...          1      1      1
# Sales Exec.                                                 1      1      1
# Sales Enablement Assoc.                                     1      1      1
# Sales Ops - Universe & Clubs                                1      1      1
# Valdosta, Taking a BITE!!! Out of HUNGER                    1      1      1
#
#                                                     Mobile  Contact Level  \
# Title
# Maintenance Mechanic A                                   0              0
# Oracle                                                   0              0
# Member                                                   0              0
# Sr. Assoc., M&A Transaction Services                     0              0
# Администратор Salesforce                                 0              0
# Assoc. - Venture Capital, Private Equity, and M...       0              0
# Salesforce Functional Configurator                       0              0
# Salesforce Evangelist                                    0              0
# Sales/Revenue Operations and Enablement                  0              0
# Salesforce + Nonprofits                                  0              0
# Salesforce - Business Solutions                          0              0
# Salesforce Commerce Cloud                                0              0
# Sr. Data Scientist – Data Science a/B Testing            0              0
# Sr. Assoc.                                               0              0
# Sr. Assoc., M&A and Strategy                             0              0
# Solution Tree Assoc. for Priority Schools in a ...       0              0
# Sales Exec.                                              0              0
# Sales Enablement Assoc.                                  0              0
# Sales Ops - Universe & Clubs                             0              0
# Valdosta, Taking a BITE!!! Out of HUNGER                 0              0
#
#                                                     Department
# Title
# Maintenance Mechanic A                                       0
# Oracle                                                       0
# Member                                                       0
# Sr. Assoc., M&A Transaction Services                         0
# Администратор Salesforce                                     0
# Assoc. - Venture Capital, Private Equity, and M...           0
# Salesforce Functional Configurator                           0
# Salesforce Evangelist                                        0
# Sales/Revenue Operations and Enablement                      0
# Salesforce + Nonprofits                                      0
# Salesforce - Business Solutions                              0
# Salesforce Commerce Cloud                                    0
# Sr. Data Scientist – Data Science a/B Testing                0
# Sr. Assoc.                                                   0
# Sr. Assoc., M&A and Strategy                                 0
# Solution Tree Assoc. for Priority Schools in a ...           0
# Sales Exec.                                                  0
# Sales Enablement Assoc.                                      0
# Sales Ops - Universe & Clubs                                 0
# Valdosta, Taking a BITE!!! Out of HUNGER                     0

# %%
df2.head(50)
# Out:
#                        Account Name First Name   Last Name  \
# 0                   1-800-GOT-JUNK?       Yves    Laflamme
# 1                       100 Thieves     Kelsey     Schultz
# 2                               10K       Nick        Hamm
# 3                               10K    Matthew        Lamb
# 4                               10K      Jared      Miller
# 5               160 Driving Academy        Rob      Dearth
# 6                  174 Power Global      David        Park
# 7                         1Password    Jessica  Coscarelli
# 8                         1Password      Emily       Payne
# 9                   1Stdibs.Com Inc  Charlotte     Noordsy
# 10                       1WorldSync      Renee      Gerami
# 11        2-10 Home Buyers Warranty    Zachary    Ratzlaff
# 12        2-10 Home Buyers Warranty       Zach    Ratzlaff
# 13        3 Creeks Technologies LLC      Scott        Aker
# 14                        3BL Media      Emily       Tuohy
# 15                     3STEP Sports      Deion      Wilson
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 18                    5P Consulting      Randy    Jasinski
# 19                    5P Consulting    Y'vonne       Sisco
# 20                           6sense      Ankit       Goyal
# 21                  6Street Digital    Johnson         Tai
# 22                        8x8, Inc.     Helena      Ostlin
# 23                        8x8, Inc.    Barbara    Phillips
# 24               A&M Wood Specialty    Raphael   Giuffrida
# 25                               A5      Bryan       Musto
# 26                    AAA Carolinas     Claire    Crabtree
# 27                AAA Club Alliance       John        Cccm
# 28                             AAGI      Brian        Cook
# 29             Ability Network Inc.      Kelli       Davis
# 30            Academic Partnerships    Mengyao        Chen
# 31                            ACASS     Shauna      Dunham
# 32         Accelerated Systems Inc.    Marcell     Alvarez
# 33                           Accern  Yugandhar           P
# 34  Access | Information Management      Cindy     Barrios
# 35               Access Development       Jodi         Lee
# 36                          AccuTec      Carla       Floyd
# 37                   Achievers Corp    Mustafa        Avci
# 38                     ACI Learning   Madeline       Doyle
# 39                     ACI Learning     Cheryl       Janda
# 40                     ACI Learning      Pedro        Lima
# 41                     ACI Learning       Vito      Lucero
# 42                     ACI Learning    William     Mathias
# 43                     ACI Learning      Dylan   Stenulson
# 44                     ACI Learning    Jessica     Walters
# 45                    ACI Worldwide      Johan      Amador
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 48                     Acra Lending      Jason    Sheridan
# 49               Actian Corporation       Paul     Navarro
#
#                                                 Title  \
# 0                              Mgr., Sales Enablement
# 1             Dir., Head of Sales Ops and Activations
# 2                                     Founder and CEO
# 3                                                 CTO
# 4                                                 COO
# 5   Head of Contact Center Operations, Truckers Ne...
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 8                               Sales Enablement Mgr.
# 9                                     Mgr., Sales Ops
# 10             Dir. of Technology Planning & Delivery
# 11                                     Sales Ops Mgr.
# 12                                     Sales Ops Mgr.
# 13                                      Owner/Founder
# 14                            Revenue Operations Mgr.
# 15                               Sales Ops Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 18                                President / Partner
# 19                                      Founder / CEO
# 20                               Sr. Integration Mgr.
# 21                               Salesforce Developer
# 22                                Sr. Mgr., Sales Ops
# 23                 Sales Onboarding & Enablement Mgr.
# 24                                Sales Ops Team Lead
# 25              VP, Head of FINS & Digital Experience
# 26                           Salesforce Administrator
# 27          Mgr. Insurance Agency Retention Sales Ops
# 28                                  Western Sales, VP
# 29                                 Sr. Mgr. Sales Ops
# 30                                     Sales Ops Mgr.
# 31                              Mgr. of Sales Support
# 32                              Sales Ops Coordinator
# 33                                    Salesforce Mgr.
# 34  Corp. Development Advisor - M&A / Corp. Partne...
# 35                                Sales Support Admin
# 36                               Sales Ops Specialist
# 37                   Mgr., Revenue Operations Systems
# 38                           Salesforce Administrator
# 39  Sr. Dir. of Salesforce Development and Integra...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 42  Global Head, Sales Enablement Services and Rev...
# 43                        Sales Enablement Specialist
# 44                               Sales Ops Specialist
# 45                           Head of Global Sales Ops
# 46  Sr. Dir. of Revenue Programs, Planning and Inc...
# 47             Sr. Mgr., Revenue Operations, Programs
# 48                                VP, Wholesale Sales
# 49                                 Support Sales Mgr.
#
#                                     Email             Phone Mobile  \
# 0           yves.laflamme@1800gotjunk.com   +1 800-468-5865    NaN
# 1                k.schultz@100thieves.com    (424) 298-0196    NaN
# 2                        nick@10kview.com               NaN    NaN
# 3                        matt@10kview.com               NaN    NaN
# 4                       jared@10kview.com               NaN    NaN
# 5           rdearth@160drivingacademy.com    (877) 350-0884    NaN
# 6           david.park@174powerglobal.com   +1 949-748-5970    NaN
# 7        jessica.coscarelli@agilebits.com    (888) 710-9976    NaN
# 8               emily.payne@1password.com    (888) 710-9976    NaN
# 9           charlotte.noordsy@1stdibs.com    (877) 721-3427    NaN
# 10                 rgerami@1worldsync.com    (866) 280-4013    NaN
# 11                    zaratzlaff@2-10.com    (720) 747-6000    NaN
# 12                     zratzlaff@2-10.com    (720) 747-6000    NaN
# 13                  scott@3creekstech.com               NaN    NaN
# 14                    etuohy@3blmedia.com    (866) 508-0993    NaN
# 15             deion.wilson@threestep.com    (781) 722-0338    NaN
# 16                vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                   ggolzari@4refuel.com   +1 888-473-3835    NaN
# 18             rjasinski@5pconsulting.biz   +1 760-652-9127    NaN
# 19               yormond@5pconsulting.biz   +1 760-652-9127    NaN
# 20                 ankit.goyal@6sense.com   +1 415-305-5951    NaN
# 21                     johnson.tai@6st.co  +1(833) 242-6439    NaN
# 22                  helena.ostlin@8x8.com    (844) 716-2409    NaN
# 23               barbara.phillips@8x8.com    (844) 716-2409    NaN
# 24         rgiuffrida@forloversofwood.com   +1 519-653-9322    NaN
# 25                      bmusto@a5corp.com    (844) 226-6344    NaN
# 26                         claire@aaa.com    (800) 222-4357    NaN
# 27             jstassi@aaamidatlantic.com    (800) 222-4357    NaN
# 28                        brianc@aagi.com  +1(888) 442-2886    NaN
# 29               kelli.davis@inovalon.com    (612) 460-4301    NaN
# 30  mengyao.chen@academicpartnerships.com    (214) 210-7300    NaN
# 31                      sdunham@acass.com    (514) 636-1099    NaN
# 32  marcellalvarez@acceleratedsystems.com   +1 519-342-2507    NaN
# 33                 yugandhar.p@accern.com   +1 347-256-8460    NaN
# 34                cbarrios@accesscorp.com    (973) 808-2885    NaN
# 35         jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN
# 36               carla.floyd@atblades.com   +1 800-336-4061    NaN
# 37              tugrul.avci@achievers.com    (888) 622-3343    NaN
# 38         madeline.doyle@acilearning.com    (719) 596-4545    NaN
# 39           cheryl.janda@acilearning.com    (719) 596-4545    NaN
# 40             pedro.lima@acilearning.com    (719) 596-4545    NaN
# 41                vlucero@leaderquest.net    (719) 596-4545    NaN
# 42           bill.mathias@acilearning.com    (719) 596-4545    NaN
# 43        dylan.stenulson@acilearning.com    (719) 596-4545    NaN
# 44        jessica.walters@acilearning.com    (719) 596-4545    NaN
# 45          johan.amador@aciworldwide.com    (844) 776-6605    NaN
# 46                  pam.bragan@acquia.com    (888) 922-7842    NaN
# 47         elizabeth.levasseur@acquia.com    (888) 922-7842    NaN
# 48         jsheridan@citadelservicing.com  +1(888) 800-7661    NaN
# 49                paul.navarro@actian.com    (650) 587-5500    NaN
#
#    Contact Level  Department
# 0     Management         NaN
# 1     Management         NaN
# 2      Executive         NaN
# 3            CXO         NaN
# 4            CXO         NaN
# 5     Management         NaN
# 6          Staff         NaN
# 7          Staff         NaN
# 8     Management         NaN
# 9     Management         NaN
# 10    Management         NaN
# 11    Management         NaN
# 12    Management         NaN
# 13     Executive         NaN
# 14    Management         NaN
# 15         Staff         NaN
# 16         Staff         NaN
# 17         Staff         NaN
# 18     Executive         NaN
# 19     Executive         NaN
# 20    Management         NaN
# 21         Staff         NaN
# 22    Management         NaN
# 23    Management         NaN
# 24         Staff         NaN
# 25    Management         NaN
# 26         Staff         NaN
# 27    Management         NaN
# 28    Management         NaN
# 29    Management         NaN
# 30    Management         NaN
# 31    Management         NaN
# 32         Staff         NaN
# 33    Management         NaN
# 34    Management         NaN
# 35         Staff         NaN
# 36         Staff         NaN
# 37    Management         NaN
# 38         Staff         NaN
# 39    Management         NaN
# 40         Staff         NaN
# 41         Staff         NaN
# 42    Management         NaN
# 43         Staff         NaN
# 44         Staff         NaN
# 45    Management         NaN
# 46    Management         NaN
# 47    Management         NaN
# 48    Management         NaN
# 49    Management         NaN

# %%
# export df2 for excel manual check
# df2.to_excel('Sales_Ops_v2.xlsx')

# %% [markdown]
# ## 3. Categorize 'Department' Field
# Fields:
# - Sales Ops
# - Sales Support
# - Sales Enablement
# - Sales
# - Finance
# - Accounting
# - FP&A
# - IT
# - Legal
# - Customer Success
# - Consulting
# - Marketing
# - HR
# - Procurement
# - FinSys
# - Operations
#
# **Top Ten Missed:**
# - Salesforce Developer (538+) **IT?**
# - Salesforce Administrator (91+)
# - Salesforce Mgr./Dir.(30+)
# - Planning Mgr. (12+)
# - Salesforce/Solution(s) Architect (19+)
# - CRO (9)
# - COO (4) **Operations?**
# - Salesforce Technical Lead (4)
# - Salesforce Trainee (4)
# - CEO & Founder / Founder and CEO (7)
# - Co-Founder (3)
# - Maintenance Mechanic (3+) **Operations?**
# - President (3)
#
#
# Double check:
# - FP&A (Planning)
#
# Ask LK:
# - 'Salesforce Developer' categorization
# - 'Salesforce/Solution(s) Architect' categorization
# - CRO/COO/CEO/Founder/Co-Founder/President
# - 'Salesforce Mgr./Dir.'
# - Other 'Support' titles ; Trainee/Mechanic/Instructor/etc.

# %% [markdown]
# ### (a) Sales Ops – all titles containing:
# - Sales Operations
# - Sales Ops
# - Revenue Operations
# - RevOps

# %%
# filter dataframe by Sales Ops titles, then set the 'Department' column equal to 'Sales Ops'
# SYNTAX: df.loc[df[‘filter column’] condition, ‘target column name’] = ‘target column value if condition is met’
df2.loc[df2['Title'].str.contains(
                                  'Sales Operations|'
                                  'Sales Ops|'
                                  'Revenue Operations|'
                                  'RevOps'
                                  ,na=False, regex=True),'Department'] = 'Sales Ops'

# df2.head()
df2[df2['Department']=='Sales Ops'].head(10)
# Out:
#                  Account Name First Name  Last Name  \
# 1                 100 Thieves     Kelsey    Schultz
# 9             1Stdibs.Com Inc  Charlotte    Noordsy
# 11  2-10 Home Buyers Warranty    Zachary   Ratzlaff
# 12  2-10 Home Buyers Warranty       Zach   Ratzlaff
# 14                  3BL Media      Emily      Tuohy
# 15               3STEP Sports      Deion     Wilson
# 22                  8x8, Inc.     Helena     Ostlin
# 24         A&M Wood Specialty    Raphael  Giuffrida
# 27          AAA Club Alliance       John       Cccm
# 29       Ability Network Inc.      Kelli      Davis
#
#                                         Title                           Email  \
# 1     Dir., Head of Sales Ops and Activations        k.schultz@100thieves.com
# 9                             Mgr., Sales Ops   charlotte.noordsy@1stdibs.com
# 11                             Sales Ops Mgr.             zaratzlaff@2-10.com
# 12                             Sales Ops Mgr.              zratzlaff@2-10.com
# 14                    Revenue Operations Mgr.             etuohy@3blmedia.com
# 15                       Sales Ops Specialist      deion.wilson@threestep.com
# 22                        Sr. Mgr., Sales Ops           helena.ostlin@8x8.com
# 24                        Sales Ops Team Lead  rgiuffrida@forloversofwood.com
# 27  Mgr. Insurance Agency Retention Sales Ops      jstassi@aaamidatlantic.com
# 29                         Sr. Mgr. Sales Ops        kelli.davis@inovalon.com
#
#               Phone Mobile Contact Level Department
# 1    (424) 298-0196    NaN    Management  Sales Ops
# 9    (877) 721-3427    NaN    Management  Sales Ops
# 11   (720) 747-6000    NaN    Management  Sales Ops
# 12   (720) 747-6000    NaN    Management  Sales Ops
# 14   (866) 508-0993    NaN    Management  Sales Ops
# 15   (781) 722-0338    NaN         Staff  Sales Ops
# 22   (844) 716-2409    NaN    Management  Sales Ops
# 24  +1 519-653-9322    NaN         Staff  Sales Ops
# 27   (800) 222-4357    NaN    Management  Sales Ops
# 29   (612) 460-4301    NaN    Management  Sales Ops

# %% [markdown]
# ### (b) Sales Support
# - containing “Sales” and “Support” but not the 4 Sales Ops titles

# %%
# create condition for containing both 'Sales' and 'Support' but none of 'Ops, Operation, or Operations'
sales_support = (df2['Title'].str.contains(r"Sales",na=False, regex=True) &\
        df2['Title'].str.contains(r"Support",na=False, regex=True) &\
        ~df2['Title'].str.contains(r"Ops|Operation|Operations",na=False, regex=True))

# apply the condition to filter the rows and then set the 'Department' column to 'Sales Support'
df2.loc[sales_support, 'Department'] = "Sales Support"

# df2.head(50)
df2[df2['Department']=='Sales Support'].head(10)
# Out:
#                              Account Name First Name    Last Name  \
# 31                                  ACASS     Shauna       Dunham
# 35                     Access Development       Jodi          Lee
# 49                     Actian Corporation       Paul      Navarro
# 58                   Acuity International     Jefrey          Joy
# 81                             Acxiom LLC       Dana     Ferguson
# 83             Adelman Travel Group, Inc.      Laura        Schad
# 89  Advanced Sterilization Products (ASP)        Ali  Balahoroglu
# 90  Advanced Sterilization Products (ASP)     Costas       Bastas
# 91  Advanced Sterilization Products (ASP)      Nikos   Klapadakis
# 92  Advanced Sterilization Products (ASP)   Patrizia     Scarponi
#
#                                                 Title  \
# 31                              Mgr. of Sales Support
# 35                                Sales Support Admin
# 49                                 Support Sales Mgr.
# 58  Sr. Salesforce Administrator / SF Team Support...
# 81                          Sr. Mgr. of Sales Support
# 83                                Mgr., Sales Support
# 89  Distribution and Sales Support Mgr. Turkey&Aze...
# 90                      Sales Rep / Technical Support
# 91         Sales Representative and Technical Support
# 92                    Sales Force Contractual Support
#
#                                  Email             Phone Mobile Contact Level  \
# 31                   sdunham@acass.com    (514) 636-1099    NaN    Management
# 35      jodi.lee@accessdevelopment.com   +1 800-840-0032    NaN         Staff
# 49             paul.navarro@actian.com    (650) 587-5500    NaN    Management
# 58  jefrey.joy@acuityinternational.com    (703) 261-1110    NaN         Staff
# 81           dana.blackburn@acxiom.com    (866) 352-3267    NaN    Management
# 83            lschad@adelmantravel.com   +1 414-410-8300    NaN    Management
# 89             ali.balahoroglu@asp.com  //1-888-783-7723    NaN    Management
# 90               costas.bastas@asp.com  //1-888-783-7723    NaN         Staff
# 91            nikos.klapadakis@asp.com  //1-888-783-7723    NaN         Staff
# 92           patrizia.scarponi@asp.com  //1-888-783-7723    NaN         Staff
#
#        Department
# 31  Sales Support
# 35  Sales Support
# 49  Sales Support
# 58  Sales Support
# 81  Sales Support
# 83  Sales Support
# 89  Sales Support
# 90  Sales Support
# 91  Sales Support
# 92  Sales Support

# %% [markdown]
# ### (c) Sales Enablement
# - containing “Enablement” but NOT the 4 Sales Ops titles

# %%
# create condition for containing both 'Enablement' but none of 'Ops, Operation, or Operations'
sales_enable = (df2['Title'].str.contains(r"Enablement",na=False, regex=True) &
        ~df2['Title'].str.contains(r"Ops|Operation|Operations",na=False, regex=True))

# apply the condition to filter the rows and then set the 'Department' column to 'Sales Support'
df2.loc[sales_enable, 'Department'] = "Sales Enablement"


# df2.head(50)
df2[df2['Department']=='Sales Enablement'].head(10)
# Out:
#                   Account Name First Name       Last Name  \
# 0              1-800-GOT-JUNK?       Yves        Laflamme
# 7                    1Password    Jessica      Coscarelli
# 8                    1Password      Emily           Payne
# 23                   8x8, Inc.    Barbara        Phillips
# 43                ACI Learning      Dylan       Stenulson
# 56   Activision Blizzard, Inc.       Dana          Dobbie
# 100          Aerohive Networks    Christi  Nicolacopoulos
# 107       Agility PR Solutions      Kevin           Black
# 116                   Airtable     Amanda        Dowdakin
# 117    Akoya Biosciences, Inc.      Laura           Faken
#
#                                                  Title  \
# 0                               Mgr., Sales Enablement
# 7                          Team Lead, Sales Enablement
# 8                                Sales Enablement Mgr.
# 23                  Sales Onboarding & Enablement Mgr.
# 43                         Sales Enablement Specialist
# 56   Global Head of Sales Enablement at Activision ...
# 100              VP, Sales Enablement & Communications
# 107                             Mgr., Sales Enablement
# 116                        Mgr., Post Sales Enablement
# 117  Assoc. Dir., Commercial Training (Sales Enable...
#
#                                    Email            Phone Mobile  \
# 0          yves.laflamme@1800gotjunk.com  +1 800-468-5865    NaN
# 7       jessica.coscarelli@agilebits.com   (888) 710-9976    NaN
# 8              emily.payne@1password.com   (888) 710-9976    NaN
# 23              barbara.phillips@8x8.com   (844) 716-2409    NaN
# 43       dylan.stenulson@acilearning.com   (719) 596-4545    NaN
# 56            dana.dobbie@activision.com  +1-310-255-2000    NaN
# 100  cnicolacopoulos@extremenetworks.com   (408) 510-6100    NaN
# 107            kevin.black@agilitypr.com   (866) 545-3745    NaN
# 116         amanda.dowdakin@airtable.com   (415) 200-2040    NaN
# 117                  lfaken@akoyabio.com   (415) 765-6980    NaN
#
#     Contact Level        Department
# 0      Management  Sales Enablement
# 7           Staff  Sales Enablement
# 8      Management  Sales Enablement
# 23     Management  Sales Enablement
# 43          Staff  Sales Enablement
# 56     Management  Sales Enablement
# 100    Management  Sales Enablement
# 107    Management  Sales Enablement
# 116    Management  Sales Enablement
# 117    Management  Sales Enablement

# %% [markdown]
# ### (d) Sales
# - NOT Sales Ops, Sales Support or Sales Enablement AND containing:
# - Sales
# - Business Development
# - Account Exec **(Exec.?)**
# - AE
# - Account Mgr.
# - Sales Development Representative
# - SDR
# - Sales Development Executive
# - SDE
# - Business Development Representative
# - BDR
# - Business Development Mgr.
# - BDM
# - Channel, Channels
#
# **Notes**:
# - should these acronyms be created and added at the beginning?

# %%
# create condition for containing any of the Sales keywords,
# but NOT being from the Sales Ops, Sales Support, or Sales Enablement departments
sales = (df2['Title'].str.contains(
                                  'Sales(?!force)|'
                                  'Business Development|'
                                  'Account Exec|'
                                  'AE|'
                                  'Account Mgr\.|'
                                  'Sales Development Representative|'
                                  'SDR|'
                                  'Sales Development Representative|'
                                  'SDE|'
                                  'Business Development Representative|'
                                  'BDR|'
                                  'Business Development Mgr\.|'
                                  'BDM|'
                                  'Channel|Channels'
                                  ,na=False, regex=True) &
                ~df2['Department'].str.contains(r"Sales Ops|Sales Support|Sales Enablement",na=False, regex=True))

# apply the condition to filter the rows and then set the 'Department' column to 'Sales Support'
df2.loc[sales, 'Department'] = "Sales"

# df2.head(50)
df2[df2['Department']=='Sales'].head(10)
# Out:
#                 Account Name First Name   Last Name  \
# 5        160 Driving Academy        Rob      Dearth
# 16            4Refuel Canada     Victor  Chatellier
# 17            4Refuel Canada       Goli     Golzari
# 28                      AAGI      Brian        Cook
# 48              Acra Lending      Jason    Sheridan
# 51  Active International Ltd     Robert      Wilson
# 53                ActiveWorx     George      Thomas
# 61                 Acumatica       John    Cheatham
# 65                 Acumatica     Louisa     Gooding
# 68                 Acumatica        Foy      Mainor
#
#                                                 Title  \
# 5   Head of Contact Center Operations, Truckers Ne...
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 28                                  Western Sales, VP
# 48                                VP, Wholesale Sales
# 51                              SVP Merchandise Sales
# 53                                        VP of Sales
# 61                  Inside Sales Mgr. (US and Canada)
# 65                      Sr. Business Development Mgr.
# 68                      ISV Business Development Mgr.
#
#                                     Email             Phone Mobile  \
# 5           rdearth@160drivingacademy.com    (877) 350-0884    NaN
# 16                vchatellier@4refuel.com   +1 888-473-3835    NaN
# 17                   ggolzari@4refuel.com   +1 888-473-3835    NaN
# 28                        brianc@aagi.com  +1(888) 442-2886    NaN
# 48         jsheridan@citadelservicing.com  +1(888) 800-7661    NaN
# 51  robert.wilson@activeinternational.com   +1 845-732-8806    NaN
# 53               gthomas@miriasystems.com   +1 484-446-3300    NaN
# 61                jcheatham@acumatica.com   +1 888-228-8300    NaN
# 65           louisa.gooding@acumatica.com   +1 888-228-8300    NaN
# 68               foy.mainor@acumatica.com   +1 888-228-8300    NaN
#
#    Contact Level Department
# 5     Management      Sales
# 16         Staff      Sales
# 17         Staff      Sales
# 28    Management      Sales
# 48    Management      Sales
# 51    Management      Sales
# 53    Management      Sales
# 61    Management      Sales
# 65    Management      Sales
# 68    Management      Sales

# %% [markdown]
# ### (e) Finance – all titles containing:
# - CFO
# - Controller
# - Controlling
# - Treasury
# - Treasurer
# - Auditor
# - Auditing
# - Finance
# - Financial
# - Tax
# - Investor Relations
# - SEC Reporting
# - Accounts Payable, AP, A/P
# - Accounts Receivable, AR, A/R
# - Investment

# %%
# make 'Department' column Finance if 'Title' column contains any financial keywords
df2.loc[df2['Title'].str.contains(
                                  'CFO|'
                                  'Controller|'
                                  'Controlling|'
                                  'Treasury'
                                  'Treasurer|'
                                  'Auditor|'
                                  'Auditing|'
                                  'Finance|'
                                  'Financial|'
                                  'Tax|'
                                  'Investor Relations|'
                                  'SEC Reporting|'
                                  'Accounts Payable|AP|A/P|'
                                  'Accounts Receivable|AR|A/R|'
                                  'Investment'
                                  ,na=False, regex=True),'Department'] = 'Finance'

# df2.head(50)
df2[df2['Department']=='Finance'].head(10)
# Out:
#                     Account Name     First Name  Last Name  \
# 229                     AppLovin            Dan       Chau
# 693      CareAR, A Xerox Company      Stephanie      Erdel
# 780   Charles River Laboratories  Chandrasekhar  Gopisetti
# 1168                   Demoboost           Anna    Decroix
# 1229              Doximity, Inc.          Perry       Gold
# 1436                    Finastra         Flavia     Siuves
# 1664             H&R Block, Inc.          Susan      Davis
# 2069                 Kraft Foods       Nathalie     Roggio
# 2103     LevitJones Holdings LLC           Olga   Levitsky
# 2231              Medallia, Inc.          Nader      Hamad
#
#                                                   Title  \
# 229                  Dir. of Tax - M&A and Tax Planning
# 693            Creative Dir. at CareAR, a Xerox Company
# 780    Principal Specialist, SAP Analytics and Planning
# 1168                            CMO & General Mgr. APAC
# 1229        VP, Investor Relations & Revenue Operations
# 1436   Head of Global Transfer Pricing and Tax Planning
# 1664                                 Master Tax Advisor
# 2069                     Mgr. Support Sales Controlling
# 2103     Managing Dir., Investment and Product Strategy
# 2231  Sr. Dir. Sales Enablement EMEA, APAC & LATAM (...
#
#                                       Email             Phone Mobile  \
# 229                   dan.chau@applovin.com    (650) 335-7190    NaN
# 693               stephanie.erdel@xerox.com    (845) 657-4202    NaN
# 780                   cgopisetti@criver.com    (781) 222-6000    NaN
# 1168                a.decroix@demoboost.com               NaN    NaN
# 1229                     pgold@doximity.com    (650) 200-3901    NaN
# 1436             flavia.siuves@finastra.com  +44-20-3320-5000    NaN
# 1664            s.davis@dataclaritycorp.com    (919) 256-6711    NaN
# 2069  nathalie.roggio@kraftheinzcompany.com               NaN    NaN
# 2103                     oal@levitjones.com  +1(800) 845-4159    NaN
# 2231                    nhamad@medallia.com    (650) 321-3000    NaN
#
#      Contact Level Department
# 229     Management    Finance
# 693     Management    Finance
# 780          Staff    Finance
# 1168           CXO    Finance
# 1229    Management    Finance
# 1436    Management    Finance
# 1664         Staff    Finance
# 2069    Management    Finance
# 2103    Management    Finance
# 2231    Management    Finance

# %% [markdown]
# ### (f) Accounting
# - all titles containing “Accounting” or “Accountant” and NOT any of the Finance titles above
#
# **Notes:**
# - no accounting titles at all?

# %%
# create condition for containing any of the Accounting keywords,
# but NOT being from Finance department
accounting = (df2['Title'].str.contains(
                                  'Accounting|'
                                  'Accountant'
                                  ,na=False, regex=True) &
        ~df2['Department'].str.contains(r"Finance",na=False, regex=True))

# apply the condition to filter the rows and then set the 'Department' column to 'Accounting'
df2.loc[accounting, 'Department'] = "Accounting"

df2[df2['Department']=='Accounting'].head(10)

## NO ACCOUNTING?? MANUAL CHECK
# Out:
# Empty DataFrame
# Columns: [Account Name, First Name, Last Name, Title, Email, Phone, Mobile, Contact Level, Department]
# Index: []

# %% [markdown]
# ### (g) FP&A - all titles containing:
# - Financial Planning and Analysis
# - Financial Planning & Analysis
# - Financial Planning, Analysis
# - Budgeting
# - Planning
# - Forecast
# - Forecasting (but not including “Sales Forecasting”)

# %%
# make 'Department' column FP&A if 'Title' column contains any financial planning keywords
df2.loc[df2['Title'].str.contains(
                                  'Financial Planning and Analysis|'
                                  'Financial Planning & Analysis|'
                                  'Financial Planning, Analysis|'
                                  'Budgeting|'
                                  'Planning|'
                                  'Forecast|'
                                  '(?<!Sales )Forecasting'
                                  ,na=False, regex=True),'Department'] = 'FP&A'

# df2.head(50)
df2[df2['Department']=='FP&A'].head(10)
# Out:
#                   Account Name First Name Last Name  \
# 10                  1WorldSync      Renee    Gerami
# 46                      Acquia        Pam    Bragan
# 134  Allegro Microsystems, Inc      Srini     Sekar
# 162        American Media Inc.   Winsford     Belle
# 176                     Ampere       John    Lautze
# 182     Amylyx Pharmaceuticals      Brett      Rice
# 183     Amylyx Pharmaceuticals     Chriss  Westphal
# 184               Amyris, Inc.      Kevin  Bussemer
# 185               Amyris, Inc.      Vilma    Decena
# 186               Amyris, Inc.      Brian   Dencker
#
#                                                  Title  \
# 10              Dir. of Technology Planning & Delivery
# 46   Sr. Dir. of Revenue Programs, Planning and Inc...
# 134  Sr. Dir. - Sales Inventory and Operations Plan...
# 162                                Dir. Corp. Planning
# 176                     SVP Manufacturing and Planning
# 182                  Lead, Inventory Mgr. and Planning
# 183              Head, Commercial Planning & Analytics
# 184                   Channel Planning Mgr., Biossance
# 185                           Production Planning Mgr.
# 186                        Assoc. Dir., Sales Planning
#
#                            Email           Phone Mobile Contact Level  \
# 10        rgerami@1worldsync.com  (866) 280-4013    NaN    Management
# 46         pam.bragan@acquia.com  (888) 922-7842    NaN    Management
# 134      ssekar@allegromicro.com  (508) 853-5000    NaN    Management
# 162           wbelle@amilink.com  (212) 545-4800    NaN    Management
# 176  jlautze@amperecomputing.com  (669) 770-3700    NaN    Management
# 182        brett_rice@amylyx.com  (617) 571-8872    NaN    Management
# 183   chriss_westphal@amylyx.com  (617) 571-8872    NaN    Management
# 184          bussemer@amyris.com  (510) 450-0761    NaN    Management
# 185            decena@amyris.com  (510) 450-0761    NaN    Management
# 186           dencker@amyris.com  (510) 450-0761    NaN    Management
#
#     Department
# 10        FP&A
# 46        FP&A
# 134       FP&A
# 162       FP&A
# 176       FP&A
# 182       FP&A
# 183       FP&A
# 184       FP&A
# 185       FP&A
# 186       FP&A

# %% [markdown]
# ### (h) IT - all titles containing:
# - Information Technology
# - Information Systems”
# - IT (with leading and trailing spaces) **or just word boundaries?**
# - IS (with leading and trailing spaces) **or just word boundaries?**
# - Systems
# - MIS (with leading and trailing spaces)
# - Data
# - Software
# - Application Development
# - Help Desk / Helpdesk
# - Network
# - Project Manager
# - Quality Assurance, QA
# - BI (with leading and trailing spaces)
# - Business Intelligence
# - Developer **ADDED**

# %%
# make 'Department' column IT if 'Title' column contains any Information Technology keywords
df2.loc[df2['Title'].str.contains(
                                  'Information Technology|'
                                  'Information Systems|'
                                  ' IT |'
                                  ' IS |'
                                  'Systems|'
                                  ' MIS |'
                                  'Data|'
                                  'Software|'
                                  'Application Development|'
                                  'Help Desk / Helpdesk|'
                                  'Network|'
                                  'Project Manager|'
                                  'Quality Assurance, QA|'
                                  ' BI |'
                                  'Business Intelligence|'
                                  'Developer'
                                  ,na=False, regex=True),'Department'] = 'IT'

# df2.head(50)
df2[df2['Department']=='IT'].head(10)
# Out:
#                   Account Name First Name Last Name  \
# 5          160 Driving Academy        Rob    Dearth
# 21             6Street Digital    Johnson       Tai
# 37              Achievers Corp    Mustafa      Avci
# 55   Activision Blizzard, Inc.        Sam     Akiki
# 73                   Acumatica       Jake    Poysti
# 87              Aduro Advisors       Quan       Dao
# 110        AIMDek Technologies       Ruju  Bhandari
# 111        AIMDek Technologies     Akriti       Jha
# 112        AIMDek Technologies      Krupa     Patel
# 113        AIMDek Technologies      Harsh      Shah
#
#                                                  Title  \
# 5    Head of Contact Center Operations, Truckers Ne...
# 21                                Salesforce Developer
# 37                    Mgr., Revenue Operations Systems
# 55                                Salesforce Developer
# 73              Mgr., Data Analytics and Visualization
# 87                      Salesforce Solutions Developer
# 110                               Salesforce Developer
# 111                               Salesforce Developer
# 112                               Salesforce Developer
# 113                               Salesforce Developer
#
#                              Email             Phone Mobile Contact Level  \
# 5    rdearth@160drivingacademy.com    (877) 350-0884    NaN    Management
# 21              johnson.tai@6st.co  +1(833) 242-6439    NaN         Staff
# 37       tugrul.avci@achievers.com    (888) 622-3343    NaN    Management
# 55    oussama.akiki@activision.com   +1-310-255-2000    NaN         Staff
# 73       jake.poysti@acumatica.com   +1 888-228-8300    NaN    Management
# 87          quan@aduroadvisors.com   +1 650 690 2060    NaN         Staff
# 110       ruju.bhandari@aimdek.com   +91 79654 04042    NaN         Staff
# 111          akriti.jha@aimdek.com   +91 79654 04042    NaN         Staff
# 112         krupa.patel@aimdek.com   +91 79654 04042    NaN         Staff
# 113          harsh.shah@aimdek.com   +91 79654 04042    NaN         Staff
#
#     Department
# 5           IT
# 21          IT
# 37          IT
# 55          IT
# 73          IT
# 87          IT
# 110         IT
# 111         IT
# 112         IT
# 113         IT

# %% [markdown]
# ### (i) Legal - all titles containing:
# - Attorney
# - Counsel
# - Esq.
#
# **Notes**:
# - 0 rows!

# %%
# make 'Department' column Legal if 'Title' column contains any Legal keywords
df2.loc[df2['Title'].str.contains(
                                  'Attorney|'
                                  'Counsel|'
                                  'Esq\.'
                                  ,na=False, regex=True),'Department'] = 'Legal'

# df2.head(50)
df2[df2['Department']=='Legal'].head(10)

## NO LEGAL TITLES AT ALL??
# Out:
# Empty DataFrame
# Columns: [Account Name, First Name, Last Name, Title, Email, Phone, Mobile, Contact Level, Department]
# Index: []

# %% [markdown]
# ### (j) Customer Success
# - Customer Success
# - Customer Services
# - Account Services
# - Customer Care
# - Client Services
# - Call Center

# %%
# make 'Department' column 'Customer Success' if 'Title' column contains any Customer Success keywords
df2.loc[df2['Title'].str.contains(
                                  'Customer Success|'
                                  'Customer Services|'
                                  'Account Services|'
                                  'Customer Care|'
                                  'Client Services|'
                                  'Call Center'
                                  ,na=False, regex=True),'Department'] = 'Customer Success'

# df2.head(50)
df2[df2['Department']=='Customer Success'].head(10)
# Out:
#                           Account Name First Name     Last Name  \
# 59                           Acumatica    Melissa      Bagliano
# 60                           Acumatica      Diana        Bowers
# 72                           Acumatica        Kim         Plank
# 76                           Acumatica      Jacob         Scism
# 77                           Acumatica        Kim        Seiger
# 78                           Acumatica      Sarah      Spangler
# 548                 Bitwise Industries       John          Palm
# 656                 Burlington Medical      Keith      Atkinson
# 897  Coca-Cola Canada Bottling Limited        Fil  Mastroiacovo
# 954                             Copado     Philip       Cromack
#
#                                                  Title  \
# 59                               Customer Success Mgr.
# 60                           Sr. Customer Success Mgr.
# 72                     Customer Success Marketing Mgr.
# 76                               Customer Success Mgr.
# 77                               Customer Success Mgr.
# 78                               Customer Success Mgr.
# 548       VP of Customer Success - Salesforce Practice
# 656        Dir., Sales Enablement and Customer Success
# 897  Call Center Operations, Sales and Customer Ser...
# 954  Team Lead, Customer Success Mgr. at Copado | S...
#
#                               Email            Phone Mobile Contact Level  \
# 59   melissa.bagliano@acumatica.com  +1 888-228-8300    NaN    Management
# 60       diana.bowers@acumatica.com  +1 888-228-8300    NaN    Management
# 72          kim.plank@acumatica.com  +1 888-228-8300    NaN    Management
# 76        jacob.scism@acumatica.com  +1 888-228-8300    NaN    Management
# 77         kim.seiger@acumatica.com  +1 888-228-8300    NaN    Management
# 78     sarah.spangler@acumatica.com  +1 888-228-8300    NaN    Management
# 548     jpalm@bitwiseindustries.com   (559) 500-3305    NaN    Management
# 656       keith.atkinson@burmed.com   (757) 888-8994    NaN    Management
# 897    fmastroiacovo@cokecanada.com  +1 844-383-2653    NaN         Staff
# 954             pcromack@copado.com  +1 415-483-0840    NaN    Management
#
#            Department
# 59   Customer Success
# 60   Customer Success
# 72   Customer Success
# 76   Customer Success
# 77   Customer Success
# 78   Customer Success
# 548  Customer Success
# 656  Customer Success
# 897  Customer Success
# 954  Customer Success

# %% [markdown]
# ### (k) Consulting - all titles containing:
# - Consultant
# - Consulting
# - Practice
# - Advisory
# - Contractor

# %%
# make 'Department' column 'Consulting' if 'Title' column contains any Consulting keywords
df2.loc[df2['Title'].str.contains(
                                  'Consultant|'
                                  'Consulting|'
                                  'Practice|'
                                  'Advisory|'
                                  'Contractor'
                                  ,na=False, regex=True),'Department'] = 'Consulting'

# df2.head(50)
df2[df2['Department']=='Consulting'].head(10)
# Out:
#                     Account Name  First Name   Last Name  \
# 88   Advanced Network Management     Eduardo   Rodriguez
# 199      Ankura Consulting Group        Alex  Marjanovic
# 313            Archima Solutions        Ryan      Raymer
# 346        Ascendix Technologies        Kate     Golovko
# 544           Bitwise Industries       Steve    Andersen
# 545           Bitwise Industries  Tequiliana      Fertil
# 546           Bitwise Industries      Rachel       Hands
# 548           Bitwise Industries        John        Palm
# 549           Bitwise Industries      Ginger      Whalen
# 608      Bottomline Technologies        Rich       Drury
#
#                                                  Title  \
# 88   Dir. of Salesforce and Business Analytics Prac...
# 199  Sr. Managing Dir. | US West Region, Discovery ...
# 313    Managing Dir., Salesforce and Mulesoft Practice
# 346                    Salesforce Practice Coordinator
# 544    VP of Salesforce Solutions, Salesforce Practice
# 545         Dir. of Partnerships - Salesforce Practice
# 546   VP of Services and Delivery, Salesforce Practice
# 548       VP of Customer Success - Salesforce Practice
# 549  VP Partnerships and Alliances | Salesforce Pra...
# 608     Dir. of Solution Consulting & Sales Enablement
#
#                                 Email            Phone Mobile Contact Level  \
# 88          eduardo.rodriguez@anm.com   (877) 266-8822    NaN    Management
# 199        alex.marjanovic@ankura.com   (214) 200-3695    NaN    Management
# 313  ryan.raymer@archimasolutions.com   (201) 431-7552    NaN    Management
# 346             kholovko@ascendix.com  +1 972-889-8090    NaN         Staff
# 544   sandersen@bitwiseindustries.com   (559) 500-3305    NaN    Management
# 545     tfertil@bitwiseindustries.com   (559) 500-3305    NaN    Management
# 546      rhands@bitwiseindustries.com   (559) 500-3305    NaN    Management
# 548       jpalm@bitwiseindustries.com   (559) 500-3305    NaN    Management
# 549     gwhalen@bitwiseindustries.com   (559) 500-3305    NaN    Management
# 608         rich.drury@bottomline.com         4.41E+11    NaN    Management
#
#      Department
# 88   Consulting
# 199  Consulting
# 313  Consulting
# 346  Consulting
# 544  Consulting
# 545  Consulting
# 546  Consulting
# 548  Consulting
# 549  Consulting
# 608  Consulting

# %% [markdown]
# ### (l) Marketing - all titles containing AND not previously categorized:
# - Marketing
# - Brand
# - Product Management
# - Demand
# - Lead Gen
# - Media Relations
# - eCommerce

# %%
# create condition for containing any of the Accounting keywords,
# but NOT being categorized yet (null Department)
marketing = (df2['Title'].str.contains(
                                  'Marketing|'
                                  'Brand|'
                                  'Product Management|'
                                  'Demand|'
                                  'Lead Gen|'
                                  'Media Relations|'
                                  'eCommerce'
                                  ,na=False, regex=True) &
        df2['Department'].isnull())

# apply the condition to filter the rows and then set the 'Department' column to 'Marketing'
df2.loc[marketing, 'Department'] = "Marketing"

df2[df2['Department']=='Marketing'].head(10)
# Out:
#                   Account Name First Name   Last Name  \
# 66                   Acumatica    Dhanish        John
# 69                   Acumatica      James     Mallory
# 74                   Acumatica      Tejal     Rastogi
# 101                   Aeroseal      Donna       Hawke
# 118              Aledade, Inc.      Lynka      Rivera
# 317       Archstone Consulting     Ileana     Gheorma
# 391                   AudioEye       Chad      Sollis
# 396  Automation Anywhere, Inc.    Claudia      Michon
# 512        Berlitz Corporation     Blanca    Escalera
# 675                       Calm     Ashley  Devincenzo
#
#                                                  Title  \
# 66                          ERP Product Marketing Mgr.
# 69                              Product Marketing Mgr.
# 74                   Marketing Mgr., Demand Generation
# 101              Strategic Marketing Mgr. - Commercial
# 118              Sr. Marketing Campains Ops Specialist
# 317  Marketing Dir., Global Demand Generation and A...
# 391                SVP, Revenue Marketing & Operations
# 396  SVP of Product and Solutions Marketing. Ex Sal...
# 512              Salesforce Marketing Cloud Specialist
# 675  Exec. Assistant to the Chief Content Officer, ...
#
#                                      Email            Phone Mobile  \
# 66              dhanish.john@acumatica.com  +1 888-228-8300    NaN
# 69             james.mallory@acumatica.com  +1 888-228-8300    NaN
# 74             tejal.rastogi@acumatica.com  +1 888-228-8300    NaN
# 101               donna.hawke@aeroseal.com  +1 937-428-9300    NaN
# 118                    lrivera@aledade.com  +1 844-370-1783    NaN
# 317           igheorma@thehackettgroup.com   (770) 225-3600    NaN
# 391               chad.sollis@audioeye.com   (866) 331-5324    NaN
# 396  claudia.michon@automationanywhere.com   (888) 484-3535    NaN
# 512            blanca.alguacil@berlitz.com  +1 609-514-9650    NaN
# 675             ashley.devincenzo@calm.com   (650) 988-8500    NaN
#
#     Contact Level Department
# 66     Management  Marketing
# 69     Management  Marketing
# 74     Management  Marketing
# 101    Management  Marketing
# 118         Staff  Marketing
# 317    Management  Marketing
# 391    Management  Marketing
# 396    Management  Marketing
# 512         Staff  Marketing
# 675    Management  Marketing

# %% [markdown]
# ### (m) HR - all titles containing:
# - Human Resources
# - HR (if not also containing Finance)
# - People
# - Personnel
# - Recruiting
# - Compensation
# - Benefits
# - HRIS

# %%
# create condition for containing any of the Accounting keywords,
# but if contains 'HR', not categorized as 'Finance'
hr_no_finance = (df2['Title'].str.contains(r"HR",na=False, regex=True) &
                 ~df2['Title'].str.contains(r"Finance",na=False, regex=True)
                )

hr = (df2['Title'].str.contains(
                                  'Human Resources|'
                                  'People|'
                                  'People|'
                                  'Personnel|'
                                  'Recruiting|'
                                  'Compensation|'
                                  'Benefits'
                                  'HRIS'
                                  ,na=False, regex=True) &
        (hr_no_finance)
     )

# apply the condition to filter the rows and then set the 'Department' column to 'Marketing'
df2.loc[hr, 'Department'] = "HR"

# df2.head(50)
df2[df2['Department']=='HR'].head(100)

# These are as close as I've gotten to the HR without Finance thing using regex, will probably just use conditions
# ((?:[^F ]|F(?!inance))+HR(?:[^F ]|F(?!inance))+)m ## excludes any words starting with 'F' before or after 'HR'
# ^(?!Finance)(?<!Finance )HR(?! Finance)
# Out:
#      Account Name First Name Last Name  \
# 4449        Xerox   Florence    Lively
#
#                                                   Title  \
# 4449  VP, Human Resources - Xerox/Parc & CHRO, FITTL...
#
#                           Email           Phone Mobile Contact Level  \
# 4449  florence.lively@xerox.com  (800) 275-9376    NaN    Management
#
#      Department
# 4449         HR

# %% [markdown]
# ### (n) Procurement – all titles containing:
# - Purchasing
# - Procurement
#
# **Note**: 0 procurement titles

# %%
# make 'Department' column 'Procurement' if 'Title' column contains any Procurement keywords
df2.loc[df2['Title'].str.contains(
                                  'Purchasing|'
                                  'Procurement'
                                  ,na=False, regex=True),'Department'] = 'Procurement'

# df2.head(50)
df2[df2['Department']=='Procurement'].head(10)

# 0 Procurement titles
# Out:
# Empty DataFrame
# Columns: [Account Name, First Name, Last Name, Title, Email, Phone, Mobile, Contact Level, Department]
# Index: []

# %% [markdown]
# ### (o) FinSys
# - Finance Systems
#
# **Note**: 0 FinSys titles

# %%
# make 'Department' column 'FinSys' if 'Title' column contains any FinSys keywords
df2.loc[df2['Title'].str.contains('Finance Systems',na=False, regex=True),'Department'] = 'FinSys'

# df2.head(50)
df2[df2['Department']=='FinSys'].head(10)

# 0 FinSys Titles
# Out:
# Empty DataFrame
# Columns: [Account Name, First Name, Last Name, Title, Email, Phone, Mobile, Contact Level, Department]
# Index: []

# %% [markdown]
# ### (p) Operations - all titles containing:
# - Operations
# - General Mgr.
# - GM
# - Loan
# - Compliance
# - M&A
# - Acquisitions
# - Business Partner
# - Business Planning
# - Plant
# - Production
# - Program Mgr.
# - Quality
# - Innovation
# - Research
# - Compliance
# - Supply Chain
# - Underwriter
# - Materials
# - Grant
# - Membership
# - Real Estate
# - Engineer
# - Engineering
# - Food
# - Design

# %%
# make 'Department' column 'Operations' if 'Title' column contains any Operations keywords
df2.loc[df2['Title'].str.contains(
                                  'Operations|'
                                  'General Mgr/.|'
                                  'GM|'
                                  'Loan|'
                                  'Compliance|'
                                  'M&A|'
                                  'Acquisitions|'
                                  'Business Partner|'
                                  'Business Planning|'
                                  'Plant|'
                                  'Production|'
                                  'Program Mgr\.|'
                                  'Quality|'
                                  'Innovation|'
                                  'Research|'
                                  'Compliance|'
                                  'Supply Chain|'
                                  'Underwriter|'
                                  'Materials|'
                                  'Grant|'
                                  'Membership|'
                                  'Real Estate|'
                                  'Engineer|'
                                  'Engineering|'
                                  'Food|'
                                  'Design'
                                  ,na=False, regex=True),'Department'] = 'Operations'

# df2.head(50)
df2[df2['Department']=='Operations'].head(10)
# Out:
#                        Account Name First Name   Last Name  \
# 5               160 Driving Academy        Rob      Dearth
# 14                        3BL Media      Emily       Tuohy
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 34  Access | Information Management      Cindy     Barrios
# 37                   Achievers Corp    Mustafa        Avci
# 42                     ACI Learning    William     Mathias
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 52                   ActiveProspect    Shannon      Wiggen
#
#                                                 Title  \
# 5   Head of Contact Center Operations, Truckers Ne...
# 14                            Revenue Operations Mgr.
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 34  Corp. Development Advisor - M&A / Corp. Partne...
# 37                   Mgr., Revenue Operations Systems
# 42  Global Head, Sales Enablement Services and Rev...
# 46  Sr. Dir. of Revenue Programs, Planning and Inc...
# 47             Sr. Mgr., Revenue Operations, Programs
# 52                         Dir. of Revenue Operations
#
#                                 Email            Phone Mobile Contact Level  \
# 5       rdearth@160drivingacademy.com   (877) 350-0884    NaN    Management
# 14                etuohy@3blmedia.com   (866) 508-0993    NaN    Management
# 16            vchatellier@4refuel.com  +1 888-473-3835    NaN         Staff
# 17               ggolzari@4refuel.com  +1 888-473-3835    NaN         Staff
# 34            cbarrios@accesscorp.com   (973) 808-2885    NaN    Management
# 37          tugrul.avci@achievers.com   (888) 622-3343    NaN    Management
# 42       bill.mathias@acilearning.com   (719) 596-4545    NaN    Management
# 46              pam.bragan@acquia.com   (888) 922-7842    NaN    Management
# 47     elizabeth.levasseur@acquia.com   (888) 922-7842    NaN    Management
# 52  shannon.wiggen@activeprospect.com   (888) 624-4159    NaN    Management
#
#     Department
# 5   Operations
# 14  Operations
# 16  Operations
# 17  Operations
# 34  Operations
# 37  Operations
# 42  Operations
# 46  Operations
# 47  Operations
# 52  Operations

# %% [markdown]
# ### (q) Executive
# - CFO
# - COO
# - CAO
# - CSO
# - CRO
# - CMO
# - CTO
# - CEO
# - President
# - Founder
# - Co-founder
# - Owner
#
# AND not already being in a Department
#
# - ?titles containing Board, Chair?

# %%
# create condition for containing any of the Executive keywords,
# but NOT being categorized yet (null Department)
executive = (df2['Title'].str.contains(
                                  'CFO|'
                                  'COO|'
                                  'CAO|'
                                  'CSO|'
                                  'CRO|'
                                  'CMO|'
                                  'CTO|'
                                  'CEO|'
                                  'President|'
                                  'Founder|'
                                  'Co-[Ff]ounder|'
                                  '^Owner'
                                  ,na=False, regex=True) &
        df2['Department'].isnull()
            )

# apply the condition to filter the rows and then set the 'Department' column to 'Marketing'
df2.loc[executive, 'Department'] = "Executive"

df2[df2['Department']=='Executive'].head(10)
# Out:
#                   Account Name First Name  Last Name                Title  \
# 2                          10K       Nick       Hamm      Founder and CEO
# 3                          10K    Matthew       Lamb                  CTO
# 4                          10K      Jared     Miller                  COO
# 13   3 Creeks Technologies LLC      Scott       Aker        Owner/Founder
# 18               5P Consulting      Randy   Jasinski  President / Partner
# 19               5P Consulting    Y'vonne      Sisco        Founder / CEO
# 93            AdvancedSales.ai       Greg       Plum                  CMO
# 105                   Agency73    Stryder  Thompkins   Co-Founder and CTO
# 106     Agile Cloud Consulting     Sharif    Shaalan        CEO & Founder
# 321                     Argano        Ron   Guadagno         Ex-CRO (CRO)
#
#                                        Email            Phone Mobile  \
# 2                           nick@10kview.com              NaN    NaN
# 3                           matt@10kview.com              NaN    NaN
# 4                          jared@10kview.com              NaN    NaN
# 13                     scott@3creekstech.com              NaN    NaN
# 18                rjasinski@5pconsulting.biz  +1 760-652-9127    NaN
# 19                  yormond@5pconsulting.biz  +1 760-652-9127    NaN
# 93                           greg@plumuc.com     302.530.5654    NaN
# 105                     stryder@agency73.com  +1 858-449-1499    NaN
# 106  sharif.shaalan@agilecloudconsulting.com     +18882445350    NaN
# 321                   rguadagno@interrel.com  +1 972-735-8716    NaN
#
#     Contact Level Department
# 2       Executive  Executive
# 3             CXO  Executive
# 4             CXO  Executive
# 13      Executive  Executive
# 18      Executive  Executive
# 19      Executive  Executive
# 93            CXO  Executive
# 105     Executive  Executive
# 106     Executive  Executive
# 321           CXO  Executive

# %% [markdown]
# ### Check for null 'Department' rows

# %%
df2.info()

# 532 null 'Department rows'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4532 entries, 0 to 4531
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Account Name   4532 non-null   object
#  1   First Name     4532 non-null   object
#  2   Last Name      4532 non-null   object
#  3   Title          4532 non-null   object
#  4   Email          4532 non-null   object
#  5   Phone          4391 non-null   object
#  6   Mobile         6 non-null      object
#  7   Contact Level  4422 non-null   object
#  8   Department     4068 non-null   object
# dtypes: object(9)
# memory usage: 318.8+ KB

# %% [markdown]
# ### Investigate null 'Department' rows

# %%
dept_check = df2.groupby('Title').count().sort_values('Account Name', ascending=False)
dept_check[dept_check['Department'] == 0].head(50)
# Out:
#                                                     Account Name  First Name  \
# Title
# Salesforce Administrator                                      79          79
# Sr. Salesforce Administrator                                  12          12
# Salesforce Architect                                           6           6
# Salesforce Solution Architect                                  5           5
# Salesforce Product Mgr.                                        5           5
# Solutions Architect                                            4           4
# Salesforce Technical Lead                                      4           4
# Salesforce Trainee                                             4           4
# Salesforce Technical Architect                                 4           4
# Maintenance Mechanic A                                         3           3
# Junior Salesforce Administrator                                3           3
# Oracle                                                         3           3
# Product Mgr.                                                   3           3
# Salesforce Assoc.                                              3           3
# Salesforce Mgr.                                                3           3
# Salesforce Platform Mgr.                                       3           3
# Sr. Product Mgr.                                               2           2
# Sr. Mgr., Salesforce                                           2           2
# Managing Dir.                                                  2           2
# Salesforce System Administrator                                2           2
# Member                                                         2           2
# Salesforce Recruiter                                           2           2
# Salesforce Business Solution Expert                            2           2
# Salesforce Engagement Mgr.                                     2           2
# Salesforce Certified Administrator                             2           2
# Lead Recruiter, G&A                                            2           2
# Principal Recruiter, G&A                                       2           2
# Salesforce Delivery Mgr.                                       2           2
# Администратор Salesforce                                       2           2
# CRM Mgr.                                                       2           2
# Assoc. Enterprise Architect - Salesforce                       2           2
# Salesforce Lead Admin                                          1           1
# Salesforce Geek, MVP                                           1           1
# Salesforce Functional Configurator                             1           1
# Salesforce Lead                                                1           1
# Salesforce Evangelist                                          1           1
# VP, Head of FINS & Digital Experience                          1           1
# Salesforce Programme Mgr.                                      1           1
# Salesforce QA                                                  1           1
# Salesforce QA (Trainee)                                        1           1
# Salesforce QA Lead                                             1           1
# Salesforce Ranger | Partner Growth Mgr.                        1           1
# Salesforce Recruitment                                         1           1
# Salesforce Resource Mgr.                                       1           1
# Salesforce Revenue Cloud Lead                                  1           1
# Salesforce Solution Architect and Sr. Mgr. at S...             1           1
# Salesforce Product Owner                                       1           1
# Salesforce Product Lead                                        1           1
# Salesforce Product Dir.                                        1           1
# Salesforce Platform Governance and Stewardship ...             1           1
#
#                                                     Last Name  Email  Phone  \
# Title
# Salesforce Administrator                                   79     79     68
# Sr. Salesforce Administrator                               12     12     12
# Salesforce Architect                                        6      6      5
# Salesforce Solution Architect                               5      5      5
# Salesforce Product Mgr.                                     5      5      4
# Solutions Architect                                         4      4      4
# Salesforce Technical Lead                                   4      4      4
# Salesforce Trainee                                          4      4      2
# Salesforce Technical Architect                              4      4      3
# Maintenance Mechanic A                                      3      3      3
# Junior Salesforce Administrator                             3      3      3
# Oracle                                                      3      3      3
# Product Mgr.                                                3      3      3
# Salesforce Assoc.                                           3      3      3
# Salesforce Mgr.                                             3      3      3
# Salesforce Platform Mgr.                                    3      3      3
# Sr. Product Mgr.                                            2      2      2
# Sr. Mgr., Salesforce                                        2      2      2
# Managing Dir.                                               2      2      1
# Salesforce System Administrator                             2      2      1
# Member                                                      2      2      2
# Salesforce Recruiter                                        2      2      2
# Salesforce Business Solution Expert                         2      2      2
# Salesforce Engagement Mgr.                                  2      2      2
# Salesforce Certified Administrator                          2      2      2
# Lead Recruiter, G&A                                         2      2      2
# Principal Recruiter, G&A                                    2      2      2
# Salesforce Delivery Mgr.                                    2      2      2
# Администратор Salesforce                                    2      2      2
# CRM Mgr.                                                    2      2      2
# Assoc. Enterprise Architect - Salesforce                    2      2      2
# Salesforce Lead Admin                                       1      1      1
# Salesforce Geek, MVP                                        1      1      1
# Salesforce Functional Configurator                          1      1      1
# Salesforce Lead                                             1      1      1
# Salesforce Evangelist                                       1      1      0
# VP, Head of FINS & Digital Experience                       1      1      1
# Salesforce Programme Mgr.                                   1      1      1
# Salesforce QA                                               1      1      1
# Salesforce QA (Trainee)                                     1      1      1
# Salesforce QA Lead                                          1      1      0
# Salesforce Ranger | Partner Growth Mgr.                     1      1      1
# Salesforce Recruitment                                      1      1      1
# Salesforce Resource Mgr.                                    1      1      1
# Salesforce Revenue Cloud Lead                               1      1      1
# Salesforce Solution Architect and Sr. Mgr. at S...          1      1      1
# Salesforce Product Owner                                    1      1      1
# Salesforce Product Lead                                     1      1      1
# Salesforce Product Dir.                                     1      1      1
# Salesforce Platform Governance and Stewardship ...          1      1      1
#
#                                                     Mobile  Contact Level  \
# Title
# Salesforce Administrator                                 0             79
# Sr. Salesforce Administrator                             0             12
# Salesforce Architect                                     0              6
# Salesforce Solution Architect                            0              5
# Salesforce Product Mgr.                                  0              5
# Solutions Architect                                      0              4
# Salesforce Technical Lead                                0              4
# Salesforce Trainee                                       0              4
# Salesforce Technical Architect                           0              4
# Maintenance Mechanic A                                   0              0
# Junior Salesforce Administrator                          0              3
# Oracle                                                   0              0
# Product Mgr.                                             0              3
# Salesforce Assoc.                                        0              3
# Salesforce Mgr.                                          0              3
# Salesforce Platform Mgr.                                 0              3
# Sr. Product Mgr.                                         0              2
# Sr. Mgr., Salesforce                                     0              2
# Managing Dir.                                            0              2
# Salesforce System Administrator                          0              2
# Member                                                   0              0
# Salesforce Recruiter                                     0              2
# Salesforce Business Solution Expert                      0              2
# Salesforce Engagement Mgr.                               0              2
# Salesforce Certified Administrator                       0              2
# Lead Recruiter, G&A                                      0              2
# Principal Recruiter, G&A                                 0              2
# Salesforce Delivery Mgr.                                 0              2
# Администратор Salesforce                                 0              0
# CRM Mgr.                                                 0              2
# Assoc. Enterprise Architect - Salesforce                 0              2
# Salesforce Lead Admin                                    0              1
# Salesforce Geek, MVP                                     0              1
# Salesforce Functional Configurator                       0              0
# Salesforce Lead                                          0              1
# Salesforce Evangelist                                    0              0
# VP, Head of FINS & Digital Experience                    0              1
# Salesforce Programme Mgr.                                0              1
# Salesforce QA                                            0              1
# Salesforce QA (Trainee)                                  0              1
# Salesforce QA Lead                                       0              1
# Salesforce Ranger | Partner Growth Mgr.                  0              1
# Salesforce Recruitment                                   0              1
# Salesforce Resource Mgr.                                 0              1
# Salesforce Revenue Cloud Lead                            0              1
# Salesforce Solution Architect and Sr. Mgr. at S...       0              1
# Salesforce Product Owner                                 0              1
# Salesforce Product Lead                                  0              1
# Salesforce Product Dir.                                  0              1
# Salesforce Platform Governance and Stewardship ...       0              1
#
#                                                     Department
# Title
# Salesforce Administrator                                     0
# Sr. Salesforce Administrator                                 0
# Salesforce Architect                                         0
# Salesforce Solution Architect                                0
# Salesforce Product Mgr.                                      0
# Solutions Architect                                          0
# Salesforce Technical Lead                                    0
# Salesforce Trainee                                           0
# Salesforce Technical Architect                               0
# Maintenance Mechanic A                                       0
# Junior Salesforce Administrator                              0
# Oracle                                                       0
# Product Mgr.                                                 0
# Salesforce Assoc.                                            0
# Salesforce Mgr.                                              0
# Salesforce Platform Mgr.                                     0
# Sr. Product Mgr.                                             0
# Sr. Mgr., Salesforce                                         0
# Managing Dir.                                                0
# Salesforce System Administrator                              0
# Member                                                       0
# Salesforce Recruiter                                         0
# Salesforce Business Solution Expert                          0
# Salesforce Engagement Mgr.                                   0
# Salesforce Certified Administrator                           0
# Lead Recruiter, G&A                                          0
# Principal Recruiter, G&A                                     0
# Salesforce Delivery Mgr.                                     0
# Администратор Salesforce                                     0
# CRM Mgr.                                                     0
# Assoc. Enterprise Architect - Salesforce                     0
# Salesforce Lead Admin                                        0
# Salesforce Geek, MVP                                         0
# Salesforce Functional Configurator                           0
# Salesforce Lead                                              0
# Salesforce Evangelist                                        0
# VP, Head of FINS & Digital Experience                        0
# Salesforce Programme Mgr.                                    0
# Salesforce QA                                                0
# Salesforce QA (Trainee)                                      0
# Salesforce QA Lead                                           0
# Salesforce Ranger | Partner Growth Mgr.                      0
# Salesforce Recruitment                                       0
# Salesforce Resource Mgr.                                     0
# Salesforce Revenue Cloud Lead                                0
# Salesforce Solution Architect and Sr. Mgr. at S...           0
# Salesforce Product Owner                                     0
# Salesforce Product Lead                                      0
# Salesforce Product Dir.                                      0
# Salesforce Platform Governance and Stewardship ...           0

# %% [markdown]
# **Missed**:
# - Salesforce (System/Certified) Administrator (100+)
# - Salesforce/Solution(s) Architect (40+)
# - Recruiter (15+)
# - Product Mgr.
# - Maintenance Mechanic
# - Member
# - Sr. Mgr., Salesforce
# - Oracle
# - VP, Head of FINS & Digital Experience
# - Assoc. Enterprise Architect - Salesforce
# - CRM Mgr.
#
# - Salesforce (Platform) Mgr./Dir./Assoc.(30+)
# - Salesforce Lead Admin
# - Salesforce Geek, MVP
# - Salesforce Functional Configurator
# - Salesforce Lead
# - Salesforce Evangelist
# - Salesforce Technical Lead
# - Salesforce Trainee
# - Salesforce Programme Mgr.
# - Salesforce QA
# - Salesforce Business Solution Expert
# - Salesforce Engagement Mgr.
# - Salesforce Delivery Mgr.
#
# **Fixed**
# Salesforce Developer (538+) **-> IT**
#
# Ideas:
# - add Developers to IT
# - 'Salesforce Admin' department for all the random Salesforce 'Mgr./Lead/Geek/Configurator/Admin/Trainee' titles?

# %% [markdown]
# ## 4. Transform Phone Numbers
# - for both Contacts and Companies:
#     - remove “+1” from all phone numbers (including the trailing space)
#
# **Notes**:
# - some phone numbers in XXX-XXX-XXXX format; want them transformed?

# %%
# '\+1 \([\d]+\) [\d]+-[\d]+ ### FOR FULL PHONE NUMBER (UNNEEDED)

# remove any '+1's from the 'Phone' column, with or without a trailing space
df2['Phone'] = df2['Phone'].astype(str).apply(lambda x: re.sub(r"\+1 ?", "", x))

# df2['Phone'].head(50)
df2[df2['Phone'].astype(str).str.contains(r"\+1 ?")].head(10)
# Out:
# Empty DataFrame
# Columns: [Account Name, First Name, Last Name, Title, Email, Phone, Mobile, Contact Level, Department]
# Index: []

# %% [markdown]
# ## 5. Transform Zip Codes

# %% [markdown]
# - Make sure Zip Code column formatted as such (to not lose leading zeroes)
#
# - No Zip Code column?

# %%
df2.head(50)
# Out:
#                        Account Name First Name   Last Name  \
# 0                   1-800-GOT-JUNK?       Yves    Laflamme
# 1                       100 Thieves     Kelsey     Schultz
# 2                               10K       Nick        Hamm
# 3                               10K    Matthew        Lamb
# 4                               10K      Jared      Miller
# 5               160 Driving Academy        Rob      Dearth
# 6                  174 Power Global      David        Park
# 7                         1Password    Jessica  Coscarelli
# 8                         1Password      Emily       Payne
# 9                   1Stdibs.Com Inc  Charlotte     Noordsy
# 10                       1WorldSync      Renee      Gerami
# 11        2-10 Home Buyers Warranty    Zachary    Ratzlaff
# 12        2-10 Home Buyers Warranty       Zach    Ratzlaff
# 13        3 Creeks Technologies LLC      Scott        Aker
# 14                        3BL Media      Emily       Tuohy
# 15                     3STEP Sports      Deion      Wilson
# 16                   4Refuel Canada     Victor  Chatellier
# 17                   4Refuel Canada       Goli     Golzari
# 18                    5P Consulting      Randy    Jasinski
# 19                    5P Consulting    Y'vonne       Sisco
# 20                           6sense      Ankit       Goyal
# 21                  6Street Digital    Johnson         Tai
# 22                        8x8, Inc.     Helena      Ostlin
# 23                        8x8, Inc.    Barbara    Phillips
# 24               A&M Wood Specialty    Raphael   Giuffrida
# 25                               A5      Bryan       Musto
# 26                    AAA Carolinas     Claire    Crabtree
# 27                AAA Club Alliance       John        Cccm
# 28                             AAGI      Brian        Cook
# 29             Ability Network Inc.      Kelli       Davis
# 30            Academic Partnerships    Mengyao        Chen
# 31                            ACASS     Shauna      Dunham
# 32         Accelerated Systems Inc.    Marcell     Alvarez
# 33                           Accern  Yugandhar           P
# 34  Access | Information Management      Cindy     Barrios
# 35               Access Development       Jodi         Lee
# 36                          AccuTec      Carla       Floyd
# 37                   Achievers Corp    Mustafa        Avci
# 38                     ACI Learning   Madeline       Doyle
# 39                     ACI Learning     Cheryl       Janda
# 40                     ACI Learning      Pedro        Lima
# 41                     ACI Learning       Vito      Lucero
# 42                     ACI Learning    William     Mathias
# 43                     ACI Learning      Dylan   Stenulson
# 44                     ACI Learning    Jessica     Walters
# 45                    ACI Worldwide      Johan      Amador
# 46                           Acquia        Pam      Bragan
# 47                           Acquia  Elizabeth   Levasseur
# 48                     Acra Lending      Jason    Sheridan
# 49               Actian Corporation       Paul     Navarro
#
#                                                 Title  \
# 0                              Mgr., Sales Enablement
# 1             Dir., Head of Sales Ops and Activations
# 2                                     Founder and CEO
# 3                                                 CTO
# 4                                                 COO
# 5   Head of Contact Center Operations, Truckers Ne...
# 6                            Salesforce Administrator
# 7                         Team Lead, Sales Enablement
# 8                               Sales Enablement Mgr.
# 9                                     Mgr., Sales Ops
# 10             Dir. of Technology Planning & Delivery
# 11                                     Sales Ops Mgr.
# 12                                     Sales Ops Mgr.
# 13                                      Owner/Founder
# 14                            Revenue Operations Mgr.
# 15                               Sales Ops Specialist
# 16                   Sales and Operations Coordinator
# 17                   Sales and Operations Coordinator
# 18                                President / Partner
# 19                                      Founder / CEO
# 20                               Sr. Integration Mgr.
# 21                               Salesforce Developer
# 22                                Sr. Mgr., Sales Ops
# 23                 Sales Onboarding & Enablement Mgr.
# 24                                Sales Ops Team Lead
# 25              VP, Head of FINS & Digital Experience
# 26                           Salesforce Administrator
# 27          Mgr. Insurance Agency Retention Sales Ops
# 28                                  Western Sales, VP
# 29                                 Sr. Mgr. Sales Ops
# 30                                     Sales Ops Mgr.
# 31                              Mgr. of Sales Support
# 32                              Sales Ops Coordinator
# 33                                    Salesforce Mgr.
# 34  Corp. Development Advisor - M&A / Corp. Partne...
# 35                                Sales Support Admin
# 36                               Sales Ops Specialist
# 37                   Mgr., Revenue Operations Systems
# 38                           Salesforce Administrator
# 39  Sr. Dir. of Salesforce Development and Integra...
# 40                           Salesforce Administrator
# 41                           Salesforce Administrator
# 42  Global Head, Sales Enablement Services and Rev...
# 43                        Sales Enablement Specialist
# 44                               Sales Ops Specialist
# 45                           Head of Global Sales Ops
# 46  Sr. Dir. of Revenue Programs, Planning and Inc...
# 47             Sr. Mgr., Revenue Operations, Programs
# 48                                VP, Wholesale Sales
# 49                                 Support Sales Mgr.
#
#                                     Email           Phone Mobile  \
# 0           yves.laflamme@1800gotjunk.com    800-468-5865    NaN
# 1                k.schultz@100thieves.com  (424) 298-0196    NaN
# 2                        nick@10kview.com             nan    NaN
# 3                        matt@10kview.com             nan    NaN
# 4                       jared@10kview.com             nan    NaN
# 5           rdearth@160drivingacademy.com  (877) 350-0884    NaN
# 6           david.park@174powerglobal.com    949-748-5970    NaN
# 7        jessica.coscarelli@agilebits.com  (888) 710-9976    NaN
# 8               emily.payne@1password.com  (888) 710-9976    NaN
# 9           charlotte.noordsy@1stdibs.com  (877) 721-3427    NaN
# 10                 rgerami@1worldsync.com  (866) 280-4013    NaN
# 11                    zaratzlaff@2-10.com  (720) 747-6000    NaN
# 12                     zratzlaff@2-10.com  (720) 747-6000    NaN
# 13                  scott@3creekstech.com             nan    NaN
# 14                    etuohy@3blmedia.com  (866) 508-0993    NaN
# 15             deion.wilson@threestep.com  (781) 722-0338    NaN
# 16                vchatellier@4refuel.com    888-473-3835    NaN
# 17                   ggolzari@4refuel.com    888-473-3835    NaN
# 18             rjasinski@5pconsulting.biz    760-652-9127    NaN
# 19               yormond@5pconsulting.biz    760-652-9127    NaN
# 20                 ankit.goyal@6sense.com    415-305-5951    NaN
# 21                     johnson.tai@6st.co  (833) 242-6439    NaN
# 22                  helena.ostlin@8x8.com  (844) 716-2409    NaN
# 23               barbara.phillips@8x8.com  (844) 716-2409    NaN
# 24         rgiuffrida@forloversofwood.com    519-653-9322    NaN
# 25                      bmusto@a5corp.com  (844) 226-6344    NaN
# 26                         claire@aaa.com  (800) 222-4357    NaN
# 27             jstassi@aaamidatlantic.com  (800) 222-4357    NaN
# 28                        brianc@aagi.com  (888) 442-2886    NaN
# 29               kelli.davis@inovalon.com  (612) 460-4301    NaN
# 30  mengyao.chen@academicpartnerships.com  (214) 210-7300    NaN
# 31                      sdunham@acass.com  (514) 636-1099    NaN
# 32  marcellalvarez@acceleratedsystems.com    519-342-2507    NaN
# 33                 yugandhar.p@accern.com    347-256-8460    NaN
# 34                cbarrios@accesscorp.com  (973) 808-2885    NaN
# 35         jodi.lee@accessdevelopment.com    800-840-0032    NaN
# 36               carla.floyd@atblades.com    800-336-4061    NaN
# 37              tugrul.avci@achievers.com  (888) 622-3343    NaN
# 38         madeline.doyle@acilearning.com  (719) 596-4545    NaN
# 39           cheryl.janda@acilearning.com  (719) 596-4545    NaN
# 40             pedro.lima@acilearning.com  (719) 596-4545    NaN
# 41                vlucero@leaderquest.net  (719) 596-4545    NaN
# 42           bill.mathias@acilearning.com  (719) 596-4545    NaN
# 43        dylan.stenulson@acilearning.com  (719) 596-4545    NaN
# 44        jessica.walters@acilearning.com  (719) 596-4545    NaN
# 45          johan.amador@aciworldwide.com  (844) 776-6605    NaN
# 46                  pam.bragan@acquia.com  (888) 922-7842    NaN
# 47         elizabeth.levasseur@acquia.com  (888) 922-7842    NaN
# 48         jsheridan@citadelservicing.com  (888) 800-7661    NaN
# 49                paul.navarro@actian.com  (650) 587-5500    NaN
#
#    Contact Level        Department
# 0     Management  Sales Enablement
# 1     Management         Sales Ops
# 2      Executive         Executive
# 3            CXO         Executive
# 4            CXO         Executive
# 5     Management        Operations
# 6          Staff               NaN
# 7          Staff  Sales Enablement
# 8     Management  Sales Enablement
# 9     Management         Sales Ops
# 10    Management              FP&A
# 11    Management         Sales Ops
# 12    Management         Sales Ops
# 13     Executive         Executive
# 14    Management        Operations
# 15         Staff         Sales Ops
# 16         Staff        Operations
# 17         Staff        Operations
# 18     Executive         Executive
# 19     Executive         Executive
# 20    Management               NaN
# 21         Staff                IT
# 22    Management         Sales Ops
# 23    Management  Sales Enablement
# 24         Staff         Sales Ops
# 25    Management               NaN
# 26         Staff               NaN
# 27    Management         Sales Ops
# 28    Management             Sales
# 29    Management         Sales Ops
# 30    Management         Sales Ops
# 31    Management     Sales Support
# 32         Staff         Sales Ops
# 33    Management               NaN
# 34    Management        Operations
# 35         Staff     Sales Support
# 36         Staff         Sales Ops
# 37    Management        Operations
# 38         Staff               NaN
# 39    Management               NaN
# 40         Staff               NaN
# 41         Staff               NaN
# 42    Management        Operations
# 43         Staff  Sales Enablement
# 44         Staff         Sales Ops
# 45    Management         Sales Ops
# 46    Management        Operations
# 47    Management        Operations
# 48    Management             Sales
# 49    Management     Sales Support

# %% [markdown]
# ## Final Export to Excel File

# %%
# export df2 for excel manual check
df2.to_excel('Sales_Ops_v3.xlsx')
